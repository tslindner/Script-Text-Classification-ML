# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_10 = pd.read_csv('futurama/results/8ch_result_min_len_10.csv')
df_20 = pd.read_csv('futurama/results/8ch_result_min_len_20.csv')
df_30 = pd.read_csv('futurama/results/8ch_result_min_len_30.csv')
df_40 = pd.read_csv('futurama/results/8ch_result_min_len_40.csv')
df_50 = pd.read_csv('futurama/results/8ch_result_min_len_50.csv')

del df_10['Unnamed: 0']
del df_20['Unnamed: 0']
del df_30['Unnamed: 0']
del df_40['Unnamed: 0']
del df_50['Unnamed: 0']

# %%
############  8 CHARACTERS

############  A CHART FOR EACH MIN LENGTH


ax1 = df_10.plot(kind='scatter', x='weight', y='nb', color='red', title='min_len_10', figsize=(10,8), label='nb', fontsize=12)
ax2 = df_10.plot(kind='scatter', x='weight', y='sgd', color='blue', ax=ax1, label='sgd')
ax3 = df_10.plot(kind='scatter', x='weight', y='rf', color='green', ax=ax1, label='rf')
ax4 = df_10.plot(kind='scatter', x='weight', y='lr', color='yellow', ax=ax1, label='lr')

ax1.set_ylabel('Score', fontsize=14)
ax1.set_xlabel('Weight', fontsize=14)
ax1.set_ylim(0, 1)


# ax1.text(1.05, 0.9, 
         
# '         matplotlib testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing'\
#          , transform=ax1.transAxes
#          , fontsize=12)


ax5 = df_20.plot(kind='scatter', x='weight', y='nb', color='red', title='min_len_20', figsize=(10,8), label='nb', fontsize=12)
ax6 = df_20.plot(kind='scatter', x='weight', y='sgd', color='blue', ax=ax5, label='sgd')
ax7 = df_20.plot(kind='scatter', x='weight', y='rf', color='green', ax=ax5, label='rf')
ax8 = df_20.plot(kind='scatter', x='weight', y='lr', color='yellow', ax=ax5, label='lr')

ax5.set_ylabel('Score', fontsize=14)
ax5.set_xlabel('Weight', fontsize=14)

# ax5.text(1, 0.8, 
         
# '         matplotlib testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing'\
#          , transform=ax1.transAxes
#          , fontsize=12)


ax9 = df_30.plot(kind='scatter', x='weight', y='nb', color='red', title='min_len_30', figsize=(10,8), label='nb', fontsize=12)
ax10 = df_30.plot(kind='scatter', x='weight', y='sgd', color='blue', ax=ax9, label='sgd')
ax11 = df_30.plot(kind='scatter', x='weight', y='rf', color='green', ax=ax9, label='rf')
ax12 = df_30.plot(kind='scatter', x='weight', y='lr', color='yellow', ax=ax9, label='lr')

ax9.set_ylabel('Score', fontsize=14)
ax9.set_xlabel('Weight', fontsize=14)

# ax9.text(1, 0.8, 
         
# '         matplotlib testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing'\
#          , transform=ax1.transAxes
#          , fontsize=12)


ax13 = df_40.plot(kind='scatter', x='weight', y='nb', color='red', title='min_len_40', figsize=(10,8), label='nb', fontsize=12)
ax14 = df_40.plot(kind='scatter', x='weight', y='sgd', color='blue', ax=ax13, label='sgd')
ax15 = df_40.plot(kind='scatter', x='weight', y='rf', color='green', ax=ax13, label='rf')
ax16 = df_40.plot(kind='scatter', x='weight', y='lr', color='yellow', ax=ax13, label='lr')

ax13.set_ylabel('Score', fontsize=14)
ax13.set_xlabel('Weight', fontsize=14)

# ax13.text(1, 0.8, 
         
# '         matplotlib testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing'\
#          , transform=ax1.transAxes
#          , fontsize=12)


ax17 = df_50.plot(kind='scatter', x='weight', y='nb', color='red', title='min_len_50', figsize=(10,8), label='nb', fontsize=12)
ax18 = df_50.plot(kind='scatter', x='weight', y='sgd', color='blue', ax=ax17, label='sgd')
ax19 = df_50.plot(kind='scatter', x='weight', y='rf', color='green', ax=ax17, label='rf')
ax20 = df_50.plot(kind='scatter', x='weight', y='lr', color='yellow', ax=ax17, label='lr')

ax17.set_ylabel('Score', fontsize=14)
ax17.set_xlabel('Weight', fontsize=14)

# ax17.text(1, 0.8, 
         
# '         matplotlib testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing'\
#          , transform=ax1.transAxes
#          , fontsize=12)


############  A CHART FOR EACH ALG



ax21 = df_10.plot(kind='scatter', x='weight', y='nb', color='red', title='Naive Bayesian', figsize=(10,8), label='>10', fontsize=12)
ax22 = df_20.plot(kind='scatter', x='weight', y='nb', color='blue', ax=ax21, label='>20')
ax23 = df_30.plot(kind='scatter', x='weight', y='nb', color='green', ax=ax21, label='>30')
ax24 = df_40.plot(kind='scatter', x='weight', y='nb', color='yellow', ax=ax21, label='>40')
ax25 = df_50.plot(kind='scatter', x='weight', y='nb', color='black', ax=ax21, label='>50')


ax21.set_ylabel('Score', fontsize=14)
ax21.set_xlabel('Weight', fontsize=14)

# ax1.text(1.05, 0.9, 
         
# '         matplotlib testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing'\
#          , transform=ax1.transAxes
#          , fontsize=12)


ax26 = df_10.plot(kind='scatter', x='weight', y='sgd', color='red', title='Stochastic Gradient Descent', figsize=(10,8), label='>10', fontsize=12)
ax27 = df_20.plot(kind='scatter', x='weight', y='sgd', color='blue', ax=ax26, label='>20')
ax28 = df_30.plot(kind='scatter', x='weight', y='sgd', color='green', ax=ax26, label='>30')
ax29 = df_40.plot(kind='scatter', x='weight', y='sgd', color='yellow', ax=ax26, label='>40')
ax30 = df_50.plot(kind='scatter', x='weight', y='sgd', color='black', ax=ax26, label='>50')

ax26.set_ylabel('Score', fontsize=14)
ax26.set_xlabel('Weight', fontsize=14)

# ax5.text(1, 0.8, 
         
# '         matplotlib testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing'\
#          , transform=ax1.transAxes
#          , fontsize=12)


ax31 = df_10.plot(kind='scatter', x='weight', y='rf', color='red', title='Random Forest', figsize=(10,8), label='>10', fontsize=12)
ax32 = df_20.plot(kind='scatter', x='weight', y='rf', color='blue', ax=ax31, label='>20')
ax33 = df_30.plot(kind='scatter', x='weight', y='rf', color='green', ax=ax31, label='>30')
ax34 = df_40.plot(kind='scatter', x='weight', y='rf', color='yellow', ax=ax31, label='>40')
ax35 = df_50.plot(kind='scatter', x='weight', y='rf', color='black', ax=ax31, label='>50')

ax31.set_ylabel('Score', fontsize=14)
ax31.set_xlabel('Weight', fontsize=14)

# ax9.text(1, 0.8, 
         
# '         matplotlib testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing'\
#          , transform=ax1.transAxes
#          , fontsize=12)


ax36 = df_10.plot(kind='scatter', x='weight', y='lr', color='red', title='Logistic Regression', figsize=(10,8), label='>10', fontsize=12)
ax37 = df_20.plot(kind='scatter', x='weight', y='lr', color='blue', ax=ax36, label='>20')
ax38 = df_30.plot(kind='scatter', x='weight', y='lr', color='green', ax=ax36, label='>30')
ax39 = df_40.plot(kind='scatter', x='weight', y='lr', color='yellow', ax=ax36, label='>40')
ax40 = df_50.plot(kind='scatter', x='weight', y='lr', color='black', ax=ax36, label='>50')

ax36.set_ylabel('Score', fontsize=14)
ax36.set_xlabel('Weight', fontsize=14)

# ax13.text(1, 0.8, 
         
# '         matplotlib testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing'\
#          , transform=ax1.transAxes
#          , fontsize=12)
# Out:
# Text(0.5,0,'Weight')

# %%
df_10 = pd.read_csv('futurama/results/4ch_result_min_len_10.csv')
df_20 = pd.read_csv('futurama/results/4ch_result_min_len_20.csv')
df_30 = pd.read_csv('futurama/results/4ch_result_min_len_30.csv')
df_40 = pd.read_csv('futurama/results/4ch_result_min_len_40.csv')
df_50 = pd.read_csv('futurama/results/4ch_result_min_len_50.csv')

del df_10['Unnamed: 0']
del df_20['Unnamed: 0']
del df_30['Unnamed: 0']
del df_40['Unnamed: 0']
del df_50['Unnamed: 0']

# %%
############  4 CHARACTERS

############  A CHART FOR EACH MIN LENGTH


ax1 = df_10.plot(kind='scatter', x='weight', y='nb', color='red', title='min_len_10', figsize=(10,8), label='nb', fontsize=12)
ax2 = df_10.plot(kind='scatter', x='weight', y='sgd', color='blue', ax=ax1, label='sgd')
ax3 = df_10.plot(kind='scatter', x='weight', y='rf', color='green', ax=ax1, label='rf')
ax4 = df_10.plot(kind='scatter', x='weight', y='lr', color='yellow', ax=ax1, label='lr')

ax1.set_ylabel('Score', fontsize=14)
ax1.set_xlabel('Weight', fontsize=14)

# ax1.text(1.05, 0.9, 
         
# '         matplotlib testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing'\
#          , transform=ax1.transAxes
#          , fontsize=12)


ax5 = df_20.plot(kind='scatter', x='weight', y='nb', color='red', title='min_len_20', figsize=(10,8), label='nb', fontsize=12)
ax6 = df_20.plot(kind='scatter', x='weight', y='sgd', color='blue', ax=ax5, label='sgd')
ax7 = df_20.plot(kind='scatter', x='weight', y='rf', color='green', ax=ax5, label='rf')
ax8 = df_20.plot(kind='scatter', x='weight', y='lr', color='yellow', ax=ax5, label='lr')

ax5.set_ylabel('Score', fontsize=14)
ax5.set_xlabel('Weight', fontsize=14)

# ax5.text(1, 0.8, 
         
# '         matplotlib testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing'\
#          , transform=ax1.transAxes
#          , fontsize=12)


ax9 = df_30.plot(kind='scatter', x='weight', y='nb', color='red', title='min_len_30', figsize=(10,8), label='nb', fontsize=12)
ax10 = df_30.plot(kind='scatter', x='weight', y='sgd', color='blue', ax=ax9, label='sgd')
ax11 = df_30.plot(kind='scatter', x='weight', y='rf', color='green', ax=ax9, label='rf')
ax12 = df_30.plot(kind='scatter', x='weight', y='lr', color='yellow', ax=ax9, label='lr')

ax9.set_ylabel('Score', fontsize=14)
ax9.set_xlabel('Weight', fontsize=14)

# ax9.text(1, 0.8, 
         
# '         matplotlib testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing'\
#          , transform=ax1.transAxes
#          , fontsize=12)


ax13 = df_40.plot(kind='scatter', x='weight', y='nb', color='red', title='min_len_40', figsize=(10,8), label='nb', fontsize=12)
ax14 = df_40.plot(kind='scatter', x='weight', y='sgd', color='blue', ax=ax13, label='sgd')
ax15 = df_40.plot(kind='scatter', x='weight', y='rf', color='green', ax=ax13, label='rf')
ax16 = df_40.plot(kind='scatter', x='weight', y='lr', color='yellow', ax=ax13, label='lr')

ax13.set_ylabel('Score', fontsize=14)
ax13.set_xlabel('Weight', fontsize=14)

# ax13.text(1, 0.8, 
         
# '         matplotlib testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing'\
#          , transform=ax1.transAxes
#          , fontsize=12)


ax17 = df_50.plot(kind='scatter', x='weight', y='nb', color='red', title='min_len_50', figsize=(10,8), label='nb', fontsize=12)
ax18 = df_50.plot(kind='scatter', x='weight', y='sgd', color='blue', ax=ax17, label='sgd')
ax19 = df_50.plot(kind='scatter', x='weight', y='rf', color='green', ax=ax17, label='rf')
ax20 = df_50.plot(kind='scatter', x='weight', y='lr', color='yellow', ax=ax17, label='lr')

ax17.set_ylabel('Score', fontsize=14)
ax17.set_xlabel('Weight', fontsize=14)

# ax17.text(1, 0.8, 
         
# '         matplotlib testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing'\
#          , transform=ax1.transAxes
#          , fontsize=12)


############  A CHART FOR EACH ALG



ax21 = df_10.plot(kind='scatter', x='weight', y='nb', color='red', title='Naive Bayesian', figsize=(10,8), label='>10', fontsize=12)
ax22 = df_20.plot(kind='scatter', x='weight', y='nb', color='blue', ax=ax21, label='>20')
ax23 = df_30.plot(kind='scatter', x='weight', y='nb', color='green', ax=ax21, label='>30')
ax24 = df_40.plot(kind='scatter', x='weight', y='nb', color='yellow', ax=ax21, label='>40')
ax25 = df_50.plot(kind='scatter', x='weight', y='nb', color='black', ax=ax21, label='>50')


ax21.set_ylabel('Score', fontsize=14)
ax21.set_xlabel('Weight', fontsize=14)

# ax1.text(1.05, 0.9, 
         
# '         matplotlib testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing'\
#          , transform=ax1.transAxes
#          , fontsize=12)


ax26 = df_10.plot(kind='scatter', x='weight', y='sgd', color='red', title='Stochastic Gradient Descent', figsize=(10,8), label='>10', fontsize=12)
ax27 = df_20.plot(kind='scatter', x='weight', y='sgd', color='blue', ax=ax26, label='>20')
ax28 = df_30.plot(kind='scatter', x='weight', y='sgd', color='green', ax=ax26, label='>30')
ax29 = df_40.plot(kind='scatter', x='weight', y='sgd', color='yellow', ax=ax26, label='>40')
ax30 = df_50.plot(kind='scatter', x='weight', y='sgd', color='black', ax=ax26, label='>50')

ax26.set_ylabel('Score', fontsize=14)
ax26.set_xlabel('Weight', fontsize=14)

# ax5.text(1, 0.8, 
         
# '         matplotlib testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing'\
#          , transform=ax1.transAxes
#          , fontsize=12)


ax31 = df_10.plot(kind='scatter', x='weight', y='rf', color='red', title='Random Forest', figsize=(10,8), label='>10', fontsize=12)
ax32 = df_20.plot(kind='scatter', x='weight', y='rf', color='blue', ax=ax31, label='>20')
ax33 = df_30.plot(kind='scatter', x='weight', y='rf', color='green', ax=ax31, label='>30')
ax34 = df_40.plot(kind='scatter', x='weight', y='rf', color='yellow', ax=ax31, label='>40')
ax35 = df_50.plot(kind='scatter', x='weight', y='rf', color='black', ax=ax31, label='>50')

ax31.set_ylabel('Score', fontsize=14)
ax31.set_xlabel('Weight', fontsize=14)

# ax9.text(1, 0.8, 
         
# '         matplotlib testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing'\
#          , transform=ax1.transAxes
#          , fontsize=12)


ax36 = df_10.plot(kind='scatter', x='weight', y='lr', color='red', title='Logistic Regression', figsize=(10,8), label='>10', fontsize=12)
ax37 = df_20.plot(kind='scatter', x='weight', y='lr', color='blue', ax=ax36, label='>20')
ax38 = df_30.plot(kind='scatter', x='weight', y='lr', color='green', ax=ax36, label='>30')
ax39 = df_40.plot(kind='scatter', x='weight', y='lr', color='yellow', ax=ax36, label='>40')
ax40 = df_50.plot(kind='scatter', x='weight', y='lr', color='black', ax=ax36, label='>50')

ax36.set_ylabel('Score', fontsize=14)
ax36.set_xlabel('Weight', fontsize=14)

# ax13.text(1, 0.8, 
         
# '         matplotlib testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing \n \
# testing testing testing testing testing testing'\
#          , transform=ax1.transAxes
#          , fontsize=12)
# Out:
# Text(0.5,0,'Weight')
