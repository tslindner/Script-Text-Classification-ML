# %%
import pandas as pd
df = pd.read_csv("output.csv")
df = df.drop(["Unnamed: 0"], axis=1)

# %%
df.groupby("Characters").count().sort_values(by="Quotes", ascending=False).head(10)
# Out:
#             Quotes
# Characters
# FRY           2629
# BENDER        2322
# LEELA         2086
# FARNSWORTH     985
# ZOIDBERG       567
# AMY            480
# HERMES         391
# ZAPP           330
# KIF            190
# CALCULON       106

# %%
mask = (df['Quotes'].str.len() >22)
df2 = df.loc[mask]

# %%
# def character_check(x):
#     if x[:8] == "ZOIDBERG" or\
#     x[:3] == "FRY" or\
#     x[:5] == "LEELA" or\
#     x[:6] == "BENDER" or\
#     x[:10] == "FARNSWORTH" or\
#     x[:3] == "AMY" or\
#     x[:6] == "HERMES" or\
#     x[:4] == "ZAPP":
#         return x


# df2['Characters_consolidated'] = df.apply(lambda row: character_check(row['Characters']), axis=1)

# %%
df2.groupby("Characters").count().sort_values(by="Quotes", ascending=False).head(10)
# Out:
#             Quotes
# Characters
# FRY           1931
# BENDER        1768
# LEELA         1611
# FARNSWORTH     804
# ZOIDBERG       420
# AMY            312
# HERMES         293
# ZAPP           279
# KIF            146
# CALCULON        90

# %%
df3 = df2.groupby("Characters").count().sort_values(by="Quotes", ascending=False).head(10)

# %%
df2.sort_values(by=["Characters"], ascending=False)
# Out:
#                Characters                                             Quotes
# 13144           ZOOKEEPER  Later, if anyone asks how I got away, tell the...
# 13210           ZOOKEEPER  Of course not. You think I'd show you my lair?...
# 13135           ZOOKEEPER      Ah, superheroes! Or should I say superzeroes!
# 13133           ZOOKEEPER  Sorry I'm late, long story. Now everybody hit ...
# 13146           ZOOKEEPER  Fool! A quip without putting me behind bars wo...
# 13215           ZOOKEEPER  Our transaction is complete. Come Solomon, to ...
# 5260   ZOIDBERG [WRITING]                           Blood...thicker...water.
# 14598   ZOIDBERG [EATING]                          I'm a doctor, she's dead.
# 14026          ZOIDBERG 1  There aren't any in this universe there aren't...
# 13978          ZOIDBERG 1  You know, maybe a certain blue lobster saw whe...
# 13976          ZOIDBERG 1                Oh that box! Too good for us is it?
# 13974          ZOIDBERG 1  And those co-workers. Always looking down on u...
# 13972          ZOIDBERG 1  As for me I design mansions, then live in them...
# 13970          ZOIDBERG 1                        So, tell me about yourself!
# 13922          ZOIDBERG 1                           We want the best letter!
# 14007          ZOIDBERG 1                           Why with the long faces?
# 5186   ZOIDBERG (SINGING)       They said I probably shouldn't be a surgeon.
# 9767    ZOIDBERG (DROWSY)                   Alright officer I'll move along.
# 14199   ZOIDBERG (CRYING)  Oh what a foolish squid I've been. I'm not ric...
# 4949    ZOIDBERG (CRYING)  That pig over there is wearing the same sandal...
# 10705            ZOIDBERG  Not bad for a city boy, huh?  By the way, I to...
# 14137            ZOIDBERG  I ate garbage yesterday and it didn't cost me ...
# 1435             ZOIDBERG                            More! More! More! More!
# 6955             ZOIDBERG               I'm sorry but we couldn't remove it.
# 9380             ZOIDBERG  I hope we all have as much tomorrow at my birth -
# 12244            ZOIDBERG  Strange. Why would Nixon, an awkward, uncomfor...
# 13047            ZOIDBERG  I've got just the thing, genuine miracle cream...
# 14061            ZOIDBERG  A fortune it is! At last, Zoidberg will live l...
# 5927             ZOIDBERG  Call them what you want. I call them a free meal.
# 14135            ZOIDBERG  Goose liver? Fish eggs?  Pah! Where's the goos...
# ...                   ...                                                ...
# 8776                ADLAI                   Uh, I'm afraid we only want one.
# 8720                ADLAI                Leela, you're 999,999 in a million!
# 8802                ADLAI  On the other hand, the children bring up a goo...
# 8804                ADLAI  Oh, alright. If you really want that one, I ca...
# 8723                ADLAI  Uh, listen: I just want you all to know your L...
# 8628                ADLAI  Nonsense. You're a space captain. That's a fin...
# 8806                ADLAI  Oh, and I suppose you were fine the way you were?
# 8630                ADLAI  Ah-ah. A package is just a box until it's deli...
# 8690                ADLAI  I don't know what else to say, so I'll just sa...
# 8688                ADLAI  I've never been good with words, which is why ...
# 8750                ADLAI  You know, seeing that strange robot force 12 c...
# 1878    AD-ROCK (SINGING)                       ...tellin' you all it's a...
# 1888              AD-ROCK   That was a thousand years ago. Now we got seven.
# 1886              AD-ROCK  Y'know we're, really not that interested in me...
# 11634            AARON SR  You stink lady! Hey Junior, she belongs in the...
# 11628            AARON SR  No I was better than great. I was the home run...
# 11694            AARON SR  Well, at least you're still the worst football...
# 11632            AARON SR  Low? It was zero you fungo! You went your whol...
# 11635            AARON JR  Forget it. This job's too cushy to give up.  A...
# 11637            AARON JR  Oh I can't help you play better than Tiny Iota...
# 11631            AARON JR                Well, I have a low batting average.
# 11651            AARON JR  Oh you got that too? I think there's a rash go...
# 11643            AARON JR  Hey lady, which one of us is in the hall of fame?
# 11641            AARON JR  OK try it again but this time keep your eye of...
# 11638            AARON JR                     OK, let's see what you can do.
# 11626            AARON JR  I'm not a hologram, though I am crummy. Hank A...
# 4966               5-EYES  Alkazar, why you are so late for our wedding? ...
# 2758             "FEMBOT"                     You couldn't afford it, honey.
# 2756             "FEMBOT"  Damn chico, one more upgrade and I'll be more ...
# 4737             "COSELL"  Hello and welcome to a remarkable championship...
#
# [11469 rows x 2 columns]

# %%
# df2.set_index("Characters", inplace=True)

# %%
# df2.loc["BENDER"]

# %%
# df2.Characters.str[:8]
# Out:
# 0             MAN
# 1             FRY
# 3         PANUCCI
# 4             FRY
# 5        MICHELLE
# 6             FRY
# 8             FRY
# 20            FRY
# 21            MAN
# 22            LOU
# 23          TERRY
# 25            FRY
# 26          WOMAN
# 28          WOMAN
# 29            FRY
# 30          LEELA
# 36          LEELA
# 37            FRY
# 39            FRY
# 40          LEELA
# 41            FRY
# 42          LEELA
# 43            FRY
# 44          LEELA
# 45          LEELA
# 46          LEELA
# 47            FRY
# 48          LEELA
# 50            FRY
# 51          LEELA
#            ...
# 15175    HOLO-ROB
# 15176    ROBOT DE
# 15177         FRY
# 15178    ROBOT DE
# 15182    ROBOT DE
# 15183       LEELA
# 15184    ROBOT DE
# 15186    ROBOT DE
# 15187      HERMES
# 15188    FARNSWOR
# 15189         AMY
# 15190       LEELA
# 15191    ROBOT DE
# 15192       LEELA
# 15193      BENDER
# 15194    ROBOT DE
# 15195         FRY
# 15198    FARNSWOR
# 15199    ZOIDBERG
# 15200    PREACHER
# 15201         FRY
# 15202    HEDONISM
# 15203         FRY
# 15204    ROBOT DE
# 15206    HEDONISM
# 15207         FRY
# 15208    ZOIDBERG
# 15209         FRY
# 15210    TINNY TI
# 15212       LEELA
# Name: Characters, Length: 11469, dtype: object

# %%
# df4 = df3[0:8]

# %%
# df4.head(8)
# Out:
#             Quotes
# Characters
# FRY           1931
# BENDER        1768
# LEELA         1611
# FARNSWORTH     804
# ZOIDBERG       420
# AMY            312
# HERMES         293
# ZAPP           279

# %%
df2[(df2.Characters == "ZOIDBERG") | (df2.Characters == "FRY") | (df2.Characters == "LEELA") | (df.Characters == "BENDER")
   | (df2.Characters == "FARNSWORTH") | (df2.Characters =='AMY')]
# Out:
# /Users/arjun.maniyar/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#