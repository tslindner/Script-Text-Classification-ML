# %%
import pandas as pd
df = pd.read_csv("clean_output_tv.csv")
df = df.drop(["Unnamed: 0"], axis=1)

# %%
df.groupby("Characters").count().sort_values(by="Quotes", ascending=False).head(10)
# Out:
#                       Quotes
# Characters
# Fry                     3996
# Bender                  3703
# Leela                   3186
# Farnsworth              1553
# Zoidberg                 987
# Amy                      930
# Hermes                   862
# Zapp                     503
# Professor Farnsworth     284
# Kif                      254

# %%
mask = (df['Quotes'].str.len() >22)
df2 = df.loc[mask]

# %%
def character_check(x):
    if x[:8] == "Zoidberg":
        return x[:8]
    
    elif x[:3] == "Fry":
        return x[:3]
    elif x[:5] == "Leela":
        return x[:5]
    elif x[:6] == "Bender":
        return x[:6]
    elif x[:10] == "Farnsworth":
        return x[:10]
    elif x[:3] == "Amy":
        return x[:3]
    elif x[:6] == "Hermes":
        return x[:6]
    elif x[:4] == "Zapp":
        return x[:4]
    else:
        return x


df2['Characters_consolidated'] = df.apply(lambda row: character_check(row['Characters']), axis=1)
# Out:
# C:\Users\timot\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df2.groupby("Characters_consolidated").count().sort_values(by="Quotes", ascending=False).head(10)
# Out:
#                          Characters  Quotes
# Characters_consolidated
# Fry                            2790    2790
# Bender                         2700    2700
# Leela                          2319    2319
# Farnsworth                     1295    1295
# Zoidberg                        702     702
# Hermes                          642     642
# Amy                             593     593
# Zapp                            403     403
# Professor Farnsworth            238     238
# Kif                             176     176

# %%
df3 = df2.groupby("Characters_consolidated").count().sort_values(by="Quotes", ascending=False).head(10)

# %%
df2.sort_values(by=["Characters_consolidated"], ascending=False)
# Out:
#                                               Characters  \
# 12310                                         πkea Robot
# 24673  welcome back to the clippie awards, honoring t...
# 24046                                               iZac
# 2156                                                iZac
# 2152                                                iZac
# 2150                                                iZac
# 2148                                                iZac
# 6696                                               iHawk
# 6691                                               iHawk
# 6678                                               iHawk
# 6676                                               iHawk
# 6680                                               iHawk
# 12417                                          Zookeeper
# 12477                                          Zookeeper
# 12460                                          Zookeeper
# 12498                                          Zookeeper
# 12426                                          Zookeeper
# 12465                                          Zookeeper
# 12428                                          Zookeeper
# 12415                                          Zookeeper
# 12503                                          Zookeeper
# 12470                                          Zookeeper
# 22977                                         Zoidsmythe
# 21905                                           Zoidberg
# 4591                                            Zoidberg
# 5608                                            Zoidberg
# 4587                                            Zoidberg
# 5599                                            Zoidberg
# 15801                                           Zoidberg
# 4583                                            Zoidberg
# ...                                                  ...
# 10522                                          Aaron Jr.
# 10527                                          Aaron Jr.
# 10539                                          Aaron Jr.
# 10531                                          Aaron Jr.
# 10533                                          Aaron Jr.
# 10547                                          Aaron Jr.
# 10537                                          Aaron Jr.
# 10534                                          Aaron Jr.
# 16496                                                ALL
# 16500                                                ALL
# 18451                                                ALL
# 12488                                          7¹¹ Clerk
# 712                                    21st-century girl
# 710                                    21st-century girl
# 17986                                          'Mr. Wong
# 17781                                  'Boobs Vanderbilt
# 8391                                          'Angle-ine
# 11310                                              "God"
# 11279                                              "God"
# 11308                                              "God"
# 11312                                              "God"
# 11314                                              "God"
# 11316                                              "God"
# 11326                                              "God"
# 11335                                              "God"
# 11306                                              "God"
# 2744                                            "Fembot"
# 2742                                            "Fembot"
# 12470                                          Zookeeper
# 22977                                         Zoidsmythe
# 21905                                           Zoidberg
# 4591                                            Zoidberg
# 5608                                            Zoidberg
# 4587                                            Zoidberg
# 5599                                            Zoidberg
# 15801                                           Zoidberg
# 4583                                            Zoidberg
# ...                                                  ...
# 10522                                          Aaron Jr.
# 10527                                          Aaron Jr.
# 10539                                          Aaron Jr.
# 10531                                          Aaron Jr.
# 10533                                          Aaron Jr.
# 10547                                          Aaron Jr.
# 10537                                          Aaron Jr.
# 10534                                          Aaron Jr.
# 16496                                                ALL
# 16500                                                ALL
# 18451                                                ALL
# 12488                                          7¹¹ Clerk
# 712                                    21st-century girl
# 710                                    21st-century girl
# 17986                                          'Mr. Wong
# 17781                                  'Boobs Vanderbilt
# 8391                                          'Angle-ine
# 11310                                              "God"
# 11279                                              "God"
# 11308                                              "God"
# 11312                                              "God"
# 11314                                              "God"
# 11316                                              "God"
# 11326                                              "God"
# 11335                                              "God"
# 11306                                              "God"
# 2744                                            "Fembot"
# 2742                                            "Fembot"
# 4722                                            "Cosell"
# 15912                                            "'Santa
#
# [18004 rows x 3 columns]

# %%
# 8 characters
df_8ch = df2[(df2.Characters_consolidated == "Zoidberg") | (df2.Characters_consolidated == "Fry") 
    | (df2.Characters_consolidated == "Leela") | (df2.Characters_consolidated == "Bender")| 
    (df2.Characters_consolidated == "Farnsworth") | (df2.Characters_consolidated =='Amy') | 
    (df2.Characters == 'Hermes') | (df2.Characters == 'Zapp')]

# %%
# 6 characters
df_6ch = df2[(df2.Characters_consolidated == "Zoidberg") | (df2.Characters_consolidated == "Fry") 
    | (df2.Characters_consolidated == "Leela") | (df2.Characters_consolidated == "Bender")| 
    (df2.Characters_consolidated == "Farnsworth") | (df2.Characters_consolidated =='Amy')]

# %%
# 4 characters
df_4ch = df2[(df2.Characters_consolidated == "Fry") | (df2.Characters_consolidated == "Leela") | (df2.Characters_consolidated == "Bender")
   | (df2.Characters_consolidated == "Farnsworth")]

# %%
# 2 characters
df_2ch = df2[(df2.Characters_consolidated == "Fry") | (df2.Characters_consolidated == "Leela")]

# %%
del df_8ch["Characters"]
del df_6ch["Characters"]
del df_4ch["Characters"]
del df_2ch["Characters"]

# %%
df_8ch = df_8ch.rename(index=str, columns={"Characters_consolidated": "Characters"})
df_6ch = df_6ch.rename(index=str, columns={"Characters_consolidated": "Characters"})
df_4ch = df_4ch.rename(index=str, columns={"Characters_consolidated": "Characters"})
df_2ch = df_2ch.rename(index=str, columns={"Characters_consolidated": "Characters"})

# %%
df_8ch.to_csv("clean_8characters_tv.csv")
df_6ch.to_csv("clean_6characters_tv.csv")
df_4ch.to_csv("clean_4characters_tv.csv")
df_2ch.to_csv("clean_2characters_tv.csv")

# %%
df_8ch.groupby("Characters").count()
# Out:
#             Quotes
# Characters
# Amy            593
# Bender        2700
# Farnsworth    1295
# Fry           2790
# Hermes         630
# Leela         2319
# Zapp           397
# Zoidberg       702

# %%
df_6ch.groupby("Characters").count()
# Out:
#             Quotes
# Characters
# Amy            593
# Bender        2700
# Farnsworth    1295
# Fry           2790
# Leela         2319
# Zoidberg       702

# %%
df_4ch.groupby("Characters").count()
# Out:
