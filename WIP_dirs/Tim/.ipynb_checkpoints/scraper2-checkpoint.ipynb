# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
from splinter import Browser
from pprint import pprint
import json
import re

# %%
index_url = "https://theinfosphere.org/Episode_Transcript_Listing"

# %%
def soupify(url):
    browser = Browser("chrome")
    browser.visit(url)
    html_code = browser.html
    soup = bs(html_code, "html.parser")
    return soup
    browser.windows[0].close()

# %%
def url_creation(extension):
    url = "https://theinfosphere.org" + extension
    return url

# %%
url_list = []

# %%
index_soup = soupify(index_url)
index_links = index_soup.select("b a")

# %%
for i in index_links:
    extension = i["href"]
    extension = url_creation(extension)
    url_list.append(extension)

# %%
url_list_tv = url_list[:-4]
url_list_movies = url_list[-4:]

# %%
characters = []
quotes = []

error_list = []

loop_char_count = 0
loop_quote_count = 0

list_length = len(url_list_tv)

for i in url_list_tv:
    
    print(i)

    loop_soup = soupify(i)
    loop_lines = loop_soup.select("p")
    loop_index = url_list_tv.index(i)
    
    if loop_index == 125 \
    or loop_index == 126 \
    or loop_index == 129 \
    or loop_index == 130 \
    or loop_index == 131 \
    or loop_index == 133 \
    or loop_index == 134 \
    or loop_index == 135 \
    or loop_index == 136 \
    or loop_index == 139:
        print("We don't want this one, trust me")
        continue

    for k in loop_lines:
        k = k.text.strip()
        k = re.sub(r'\[[^)]*\]', '', k)
        k = re.sub(r'\([^)]*\)', '', k)
        k = re.sub(r'\<[^)]*\>', '', k)
        k = re.sub(r'\n', '', k)



        if len(k) > 0 and ":" in k:
            k = k.split(":")
            
            if len(k[0]) > 0 and k[0] != " " and len(k[1]) > 0:

                loop_character = k[0]
                loop_character = loop_character.strip()

                if loop_character[0] == "⨂":
                    loop_character = loop_character[1:]

                characters.append(loop_character)
                loop_char_count += 1
                print("char = " + loop_character)


                loop_quote = k[1:]

                if len(loop_quote) > 1:
                    "".join(loop_quote)

                loop_quote = loop_quote[0].strip()
                quotes.append(loop_quote)
                loop_quote_count += 1
                print("quote = " + loop_quote)
                
            else:
                print(f"Something is wrong here")
        
        else:
            print(f"Empty <p> at {i}")



    if loop_char_count != loop_quote_count:
        error_list.append(url_list_tv.index(i))
        
    loop_char_list = 0
    loop_quote_list = 0
        
    print(f"Finished parsing #{loop_index} of {list_length}")
# Out:
# https://theinfosphere.org/Transcript:Space_Pilot_3000
# char = Fry
# quote = Space. It seems to go on and on forever. But then you get to the end and the gorilla starts throwing barrels at you.
# char = Fry
# quote = And that's how you play the game!
# char = Boy
# quote = You stink, loser!
# char = Panucci
# quote = Hey, Fry. Pizza goin' out! C'mon!!
# char = Fry
# quote = Michelle, baby! Where you going?
# char = Michelle
# quote = It's not working out, Fry.  I put your stuff out on the sidewalk!
# char = Fry
# quote = I hate my life, I hate my life, I hate my life.
# char = Bike Thief
# quote = Happy new year!
# char = Fry
# quote = Hello? Pizza delivery for, uh ...  Here's to another lousy millennium.
# char = Crowd
# quote = Ten!
# char = Crowd
# quote = Neuf!
# char = Crowd
# quote = Otto!
# char = Crowd
# quote = Saba!
# char = Crowd
# quote = Eksi!
# char = Crowd
# quote = Wu!
# char = Crowd
# quote = Char!
# char = Crowd
# quote = Thathu!
# char = Crowd
# quote = Nee!
# ...

# %%
len(characters)
# Out:
# 25243

# %%
len(quotes)
# Out:
# 25243

# %%
characters[15300:]
# Out:
# ['Robot Devil',
#  'Leela',
#  'Robot Devil',
#  'Leela',
#  'Leela',
#  'Robot Devil',
#  'Leela',
#  'Robot Devil',
#  'Hermes',
#  'Farnsworth',
#  'Amy',
#  'Leela',
#  'Robot Devil',
#  'Leela',
#  'Leela',
#  'Bender',
#  'Robot Devil',
#  'Fry',
#  'Nixon',
#  'Zapp',
#  'Farnsworth',
#  'Zoidberg',
#  'Preacherbot',
#  'Fry',
#  'Hedonismbot',
#  'Fry',
#  'Robot Devil',
#  'Nixon',
#  'Hedonismbot',
#  'Fry',
#  'Zoidberg',
#  'Fry',
#  'Tinny Tim',
#  'Zoidberg',
#  'Leela',
#  'Hermes',
#  'Leela',
#  'Hermes',
#  'Fry',
#  'Hermes',
#  'Bender',
#  'Hermes',
#  'Amy',
#  'Hermes',
#  'Zoidberg',
#  'Hermes',
#  'Hermes',
#  'Farnsworth',
#  'Hermes',
#  'Farnsworth',
#  'Farnsworth',
#  'Fry',
#  'Farnsworth',
#  'Farnsworth',
#  'Farnsworth',
#  'Staff',
#  'Farnsworth',
#  'Staff',
#  'Farnsworth',
#  'Staff',
#  'Farnsworth',
#  'Fry',
#  'Farnsworth',
#  'Farnsworth',
#  'Leela',
#  'Farnsworth',
#  'Farnsworth',
#  'Staff',
#  'Bender',
#  'All',
#  'Cubert',
# ...

# %%
quotes[15300:]
# Out:
# ["Very well,\nThen I'll take what I want from Leela.",
#  'Whoa!',
#  'Leela has promised me her hand.',
#  'Fry, you do not understand.',
#  "I should have revealed I've been deafened by Bender,\nThe shame,\nThe shame,\nBut I feared you'd stop writing this musical splendour,\nDeception's the curse of my whimsical gender,\nHe gave me mechanical ears,\nEffective though just a bit garish,\nIn return without shedding a tear,\nI agreed that I'd give him my hand--",
#  'In marriage!',
#  'What?',
#  "You'd give me your hand in marriage.",
#  'Is this really happening or just being staged?',
#  "It can't be real--",
#  'Not if Leela is engaged.',
#  "That isn't what I meant,\nThat isn't what I signed.",
#  'Print.',
#  "I'll give you my hand...",
#  'and   In marriage.',
#  'The use of words expressing something other than their literal intention,\nNow that is "irony".',
# ...

# %%
df = pd.DataFrame({"Characters" : characters,
                  "Quotes" : quotes})
df
# Out:
#        Characters                                             Quotes
# 0             Fry  Space. It seems to go on and on forever. But t...
# 1             Fry                  And that's how you play the game!
# 2             Boy                                  You stink, loser!
# 3         Panucci                 Hey, Fry. Pizza goin' out! C'mon!!
# 4             Fry                   Michelle, baby! Where you going?
# 5        Michelle  It's not working out, Fry.  I put your stuff o...
# 6             Fry    I hate my life, I hate my life, I hate my life.
# 7      Bike Thief                                    Happy new year!
# 8             Fry  Hello? Pizza delivery for, uh ...  Here's to a...
# 9           Crowd                                               Ten!
# 10          Crowd                                              Neuf!
# 11          Crowd                                              Otto!
# 12          Crowd                                              Saba!
# ...

# %%
df.to_csv("output_tv.csv")

# %%
error_list
# Out:
# []

# %%
test = quotes[25241]

# %%
test2 = re.sub(r'\n', '', test)

# %%
test2
# Out:
# "Yes.Listen. I've got a new job, and... well... I'm going to have to dump you."
