# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
from splinter import Browser
from pprint import pprint
import json

# %%
index_url = "http://www.imsdb.com/TV/Futurama.html"

# %%
def soupify(url):
    browser = Browser("chrome")
    browser.visit(url)
    html_code = browser.html
    soup = bs(html_code, "html.parser")
    return soup
    browser.windows[0].close()

# %%
def url_creation(extension):
    url = "http://www.imsdb.com" + extension
    return url

# %%
url_list1 = []
url_list2 = []

# %%
index_soup = soupify(index_url)
index_links = index_soup.select("p a")

# %%
for i in index_links:
    extension = i["href"]
    extension = url_creation(extension)
    url_list1.append(extension)

# %%
characters = []
quotes = []
loop_quote = []
quote_switch = False
beginning = 2

for i in url_list1:
    loop_soup = soupify(i)
    loop_soup = loop_soup.select_one("p a")["href"]
    loop_soup = url_creation(loop_soup)
    loop_soup = soupify(loop_soup)
    loop_soup = loop_soup.select_one("pre").text.strip()
    loop_soup = loop_soup.split("\n")
    
    for j in loop_soup:
        j = j.strip()
        
        if beginning != 0:
            beginning -= 1
            
        else:

            if quote_switch == False:
                if j.isupper():
                    if j == "The End":
                        beginning = 2
                    else:
                        characters.append(j)
                        quote_switch = True
                continue

            else:
                if j.isupper() or j.startswith("[") or len(j) < 1:
                    quote_switch = False
                    quote = " ".join(loop_quote)
                    quotes.append(quote)
                    loop_quote = []
                else:
                    loop_quote.append(j)

# %%
# del characters[15214]
# del characters[0]
# del quotes[0]

# %%
len(characters)
# Out:
# 15213

# %%
len(quotes)
# Out:
# 15213

# %%
df = pd.DataFrame({"Characters" : characters,
                  "Quotes" : quotes})
df
# Out:
#         Characters                                             Quotes
# 0              MAN  (voice-over) Space. It seems to go on and on f...
# 1              FRY                  And that's how you play the game!
# 2              KID                                  You stink, loser!
# 3          PANUCCI                 Hey, Fry. Pizza goin' out! C'mon!!
# 4              FRY                   Michelle, baby! Where you going?
# 5         MICHELLE  It's not working out, Fry.   I put your stuff ...
# 6              FRY      I hate my life I hate my life I hate my life.
# 7       BIKE THIEF                                    Happy new year!
# 8              FRY  Hello? Pizza delivery for......Icy Wiener?! Aw...
# 9            CROWD                                               Ten!
# 10           CROWD                                              Neuf!
# 11           CROWD                                              Otto!
# 12           CROWD                                             Sabaa!
# 13           CROWD                                              Eksi!
# 14           CROWD                                                Wu!
# 15           CROWD                                             Chaar!
# 16           CROWD                                            Thathu!
# 17           CROWD                                                Wu!
# 18           CROWD                                               One!
# 19             FRY                                          What the?
# 20             FRY  My God! It's the future. My parents, my co-wor...
# 21             MAN   (dramatically) Welcome to the world of tomorrow!
# 22             LOU         Why do you always have to say it that way?
# 23           TERRY  Haven't you ever heard of a little thing calle...
# 24             LOU                                Have a nice future.
# 25             FRY                 Cool! Just like in Star Trek!  Ow!
# 26           WOMAN                        Good afternoon, sir.  Name?
# 27             FRY                                           Uh, Fry.
# 28           WOMAN  I'm Leela. Now it's New Year's Eve so I'd like...
# 29             FRY                          Can I ask you a question?
# ...            ...                                                ...
# 15183        LEELA              (singing) Fry, you do not understand.
# 15184  ROBOT DEVIL                          (singing) ...In marriage!
# 15185        LEELA                                              What?
# 15186  ROBOT DEVIL     (singing) You'd give me your hand in marriage.
# 15187       HERMES  (singing) Is this really happening or just bei...
# 15188   FARNSWORTH                       (singing) It can't be real -
# 15189          AMY                 (singing) Not if Leela is engaged!
# 15190        LEELA                 (singing) That isn't what I meant,
# 15191  ROBOT DEVIL  (singing) You should have checked the wording ...
# 15192        LEELA                 (reading) I'll give you my hand...
# 15193       BENDER  (singing) The use of words expressing somethin...
# 15194  ROBOT DEVIL  (singing) I will marry her now and confine her...
# 15195          FRY  (singing) Destiny has cheated me by forcing me...
# 15196        NIXON                                             Arooo!
# 15197         ZAPP                                 Bray-vo! Enn-core!
# 15198   FARNSWORTH  (singing) I can't believe the devil is so unfo...
# 15199     ZOIDBERG  (singing) I can't believe everyone is just ad-...
# 15200  PREACHERBOT               (singing) By the power vested in me,
# 15201          FRY                          No!  Stop! Take my hands!
# 15202  HEDONISMBOT  Surgery in an opera? How wonderfully decadent ...
# 15203          FRY  My hands. My horrible human hands. And what di...
# 15204  ROBOT DEVIL  I cleaned them. Now if you'll excuse me it's m...
# 15205        NIXON                                               Huh?
# 15206  HEDONISMBOT      Less reality, more fantasy. Resume the opera.
# 15207          FRY                          But I can't play anymore.
# 15208     ZOIDBERG  (shouting) Yes you can. The beauty was in your...
# 15209          FRY                            Ah! Ooo, ah, whoa, hey!
# 15210    TINNY TIM  (shouting) Extra! Extra! Greatest opera of all...
# 15211     ZOIDBERG                                   I'll take eight!
# 15212        LEELA  Please don't stop playing Fry. I wanna hear ho...
#
# [15213 rows x 2 columns]

# %%
df.to_csv("output.csv")
