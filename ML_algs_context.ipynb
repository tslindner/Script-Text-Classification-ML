# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import nltk

import warnings; warnings.simplefilter('ignore')

from scipy.sparse import csr_matrix
from scipy.sparse import hstack

from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
df = pd.read_csv("futurama/8ch_CSVs/8ch_futurama_binary_41.csv")
len(df)
# Out:
# 25550

# %%
df2 = df[["Fry", "Bender", "Leela", "Farnsworth", "Hermes", "Zoidberg", "Amy", "Zapp", "Other"]]
df_quotes = df["Quotes"].values.astype('U')
# X = df2.values.astype('U')
len(df_quotes)
# Out:
# 25550

# %%
# Initialize a CountVectorizer object: count_vectorizer
count_vec = CountVectorizer(stop_words="english", analyzer='word', 
                            ngram_range=(1, 1), max_features=None)

# Transforms the data into a bag of words
count_quotes = count_vec.fit_transform(df_quotes)
count_quotes.shape

# bag_of_words = count_vec.transform(df_quotes)

# Print the first 10 features of the count_vec
# print("Every feature:\n{}".format(count_vec.get_feature_names()))
# print("\nEvery 3rd feature:\n{}".format(count_vec.get_feature_names()[::3]))
# Out:
# (25550, 16852)

# %%
# print("Vocabulary size: {}".format(len(count_train.vocabulary_)))
# print("Vocabulary content:\n {}".format(count_train.vocabulary_))

# %%
tf_transformer = TfidfTransformer(smooth_idf=False, sublinear_tf=False, norm=None)
quote_train_tf = tf_transformer.fit_transform(X=count_quotes)
quote_train_tf.shape
# Out:
# (25550, 16852)

# %%
df2_matrix = csr_matrix(df2.values)

# %%
df2_matrix_combined = hstack([quote_train_tf,df2_matrix]).toarray()

# %%
# df2_matrix_combined

# %%
df2_final = pd.DataFrame(df2_matrix_combined)

# %%
df2_final["Characters"] = df["Characters"]

# %%
df2_matrix_combined = pd.DataFrame(df2_matrix_combined)
df2_matrix_combined['Quotes'] = df['Quotes']

# %%
X = df2_matrix_combined
X.shape
# Out:
# (25550, 16862)

# %%
y = df2_final["Characters"].values.astype('U')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
test_train = X_train['Quotes']
test_test = X_test['Quotes']

del X_train['Quotes']
del X_test['Quotes']

# %%
# clf_nb = MultinomialNB().fit(X_train, y_train)
# predicted_nb = clf_nb.predict(X_test)
# print("Naive Bayesian: ", np.mean(predicted_nb == y_test))

# %%
test_test = test_test.reset_index()
del test_test['index']
test_test['Quotes']
# Out:
# 0       Huddled together in fear like lice in a burnin...
# 1                      Whose that?  The Queen of England?
# 2                                   That's not necessary.
# 3                             You're back from the dead?!
# 4       Probably not. But I love you and I'm gonna kic...
# 5       A holophonor? Only a few people in the whole u...
# 6                                            Yes, Doctor.
# 7       A patriot of the highest order has volunteered...
# 8       Ah, buck up, meatloaf. Bender'll take you out ...
# 9           Uh, sorry, Bender, that's just a phone booth.
# 10                                                    No!
# 11      C'mon, Bender. If you're done scamming Beck, w...
# 12      Warning, perform virus scan? I'm waiting for p...
# 13                                    What are you doing?
# 14      Of course I'm awake. You wouldn't stop waking ...
# 15      Oh so just 'cause a robot wants to kill humans...
# 16                     I told you, my name is Dr. Cahill.
# 17      I'm in disguise 'cause I'm thinking of escapin...
# 18      It's all thanks to you, Leela. You stood by me...
# 19                                  Fry? Are you alright?
# 20                Is Nibbler stoked for the big pet show?
# 21                         Come to Daddy, sweetie-ookums.
# 22                                               Not you.
# 23      The shame is too great. It's time to end this!...
# 24                                      Initiate snu-snu!
# 25      Now this is why you gotta use cast-iron cookware.
# 26      Yes, let's all talk about Leela's personal lif...
# 27                                         Now we get it!
# 28      Listen up, piggies! I want a hovercopter. And ...
# 29      We're rolling in three, two... What? We're alr...
#                               ...
# 6358    Then I have no choice but to do something so p...
# 6359    Now put that greasy rat outside and we'll tow ...
# 6360    I'm ready. I'll take that big purple dinosaur,...
# 6361                                               Check!
# 6362                            You die. Or as you put it
# 6363                                           Brilliant!
# 6364                              And you are outta here!
# 6365                                    What?  Oh.  Okay.
# 6366                                         Fry, face it
# 6367                   And I, I could be an acting coach!
# 6368    Alright, when we get to Earth. But please don'...
# 6369                          Thanks for the help, Leela.
# 6370                                                  Ow!
# 6371                             Prepare to be surprised.
# 6372    It seems to be working at only half-capacity, ...
# 6373    Oh, if only we hadn't flown penguins to Pluto ...
# 6374       Acting like a moron won't bring your dog back.
# 6375          Does anyone else smell burning dragon beak?
# 6376                                       Planet Express
# 6377                           Let's all go to the lobby!
# 6378                         Also, my shoe that fell off.
# 6379    I was attacked by a vicious, motorised sled. T...
# 6380    This Xmas Day session of court will come to or...
# 6381                                                  Ew!
# 6382                                     Sure thing, pal.
# 6383    My God, I really can read minds. I have a supe...
# 6384          Why are you cheering, Fry? You're not rich!
# 6385    The Spiderians, though weak and woman-like on ...
# 6386                                 I'll save you, Pops!
# 6387    It's true. I disguised myself as a Femputer so...
# Name: Quotes, Length: 6388, dtype: object

# %%
# for i in range(100):
#     if len(test_test['Quotes'][i]) > 50:
#         print(predicted_nb[i], y_test[i], test_test['Quotes'][i])

# %%
# clf_sgq = SGDClassifier().fit(X_train, y_train)
# predicted_sgd = clf_sgq.predict(X_test)
# print("SGD: ", np.mean(predicted_sgd == y_test))

# %%
# clf_rf = RandomForestClassifier().fit(X_train, y_train)
# predicted_rf = clf_rf.predict(X_test)
# print("Random Forest: ", np.mean(predicted_rf == y_test))
# Out:
# Random Forest:  0.3454915466499687

# %%
clf = KNeighborsClassifier().fit(X_train, y_train)
predicted = clf.predict(X_test)
np.mean(predicted == y_test)

# %%
clf = GradientBoostingClassifier().fit(X_train, y_train)
predicted = clf.predict(X_test)
np.mean(predicted == y_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-7cfad137b09c> in <module>()
# ----> 1 clf = GradientBoostingClassifier().fit(X_train, y_train)
#       2 predicted = clf.predict(X_test)
#       3 np.mean(predicted == y_test)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\ensemble\gradient_boosting.py in fit(self, X, y, sample_weight, monitor)
#    1032         # fit the boosting stages
#    1033         n_stages = self._fit_stages(X, y, y_pred, sample_weight, random_state,
# -> 1034                                     begin_at_stage, monitor, X_idx_sorted)
#    1035         # change shape of arrays after fit (early-stopping or additional ests)
#    1036         if n_stages != self.estimators_.shape[0]:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\ensemble\gradient_boosting.py in _fit_stages(self, X, y, y_pred, sample_weight, random_state, begin_at_stage, monitor, X_idx_sorted)
#    1087             y_pred = self._fit_stage(i, X, y, y_pred, sample_weight,
#    1088                                      sample_mask, random_state, X_idx_sorted,
# -> 1089                                      X_csc, X_csr)
#    1090
#    1091             # track deviance (= loss)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\ensemble\gradient_boosting.py in _fit_stage(self, i, X, y, y_pred, sample_weight, sample_mask, random_state, X_idx_sorted, X_csc, X_csr)
#     786             else:
#     787                 tree.fit(X, residual, sample_weight=sample_weight,
# --> 788                          check_input=False, X_idx_sorted=X_idx_sorted)
#     789
#     790             # update tree leaves
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1122             sample_weight=sample_weight,
#    1123             check_input=check_input,
# -> 1124             X_idx_sorted=X_idx_sorted)
#    1125         return self
#    1126
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     360                                            min_impurity_split)
#     361
# --> 362         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     363
#     364         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
yes_counter = 0
no_counter = 0


for i in range(len(predicted_rf)):
    if len(str(test_test['Quotes'][i])) > 50:
        yes_counter += 1
        if predicted_rf[i] == y_test[i]:
            print(predicted_rf[i], '  ', y_test[i], '   ', test_test['Quotes'][i])
            
        else:
#           Adds bold text for the incorrect lines
            print(predicted_rf[i], '  ', y_test[i], '   ', ('\033[1m' + str(test_test['Quotes'][i]) + '\033[0m'))

    else:
        no_counter +=1
      
print(yes_counter)
print(no_counter)
# Out:
# Fry    Hermes     Huddled together in fear like lice in a burning wig.
# Bender    Bender     Probably not. But I love you and I'm gonna kick his ass till I win you back.
# Other    Leela     A holophonor? Only a few people in the whole universe can play that, and they're not very good at it.
# Other    Zapp     A patriot of the highest order has volunteered to lead us to them.
# Fry    Bender     Ah, buck up, meatloaf. Bender'll take you out tonight and cheer you up. What do you wanna do? And I mean anything. You have the power! Name it and I'm there. You the man!
# Hermes    Fry     C'mon, Bender. If you're done scamming Beck, we're heading home.
# Fry    Bender     Warning, perform virus scan? I'm waiting for porn over here.
# Other    Leela     Of course I'm awake. You wouldn't stop waking me.  Where am I?
# Other    Bender     Oh so just 'cause a robot wants to kill humans that makes him a radical?
# Bender    Other     I'm in disguise 'cause I'm thinking of escaping. You in? Or do I gotta kill you so you don't squeal?
# Fry    Other     It's all thanks to you, Leela. You stood by me and exposed my private medical records, even after I begged you not to.
# Other    Zoidberg     The shame is too great. It's time to end this! Huh-yah! Feh!
# Fry    Farnsworth     Yes, let's all talk about Leela's personal life later. But right now we have business to attend to.
# Leela    Other     Listen up, piggies! I want a hovercopter. And a non-marked sandwich. And a new face with, like, a... A Hugh Grant look.
# Other    Zoidberg     We're rolling in three, two... What? We're already rolling?
# Other    Other     Are you kidding? I need more lipstick! Much more!  Ooh, yeah! That's the stuff! Men love it when you really glob it on.
# Farnsworth    Farnsworth     Oh, a lesson in not changing history from Mr. I'm-My-Own-Grandpa! Let's get the hell out of here already! Screw history!
# Other    Other     I send you to kill them and they're not even maimed? That's what I get for sending boys to do a mom's job.
# Zoidberg    Other     And on Xmas eve, the most wonderful night of the  ooofff.
# Amy    Other     I have decided, after little thought, to return your genders.
# Fry    Fry     Ooh. "Reasons unknown." Now that's the sort of hook that grabs the attention of me, the viewer.
# Leela    Leela     Aw... I'm sure it's fine by the standards of a gross alien monster. Blech!
# Leela    Fry     Hey, Alcazar, you left somebody off the guest list.
# Fry    Fry     So, uh, Flexo. Sorry about crushing your body like that. You OK now?
# Other    Other     My fellow Earthlicans, commence preparations for our date with Yivo.
# Leela    Other     Right on! In order for any of this to make any sense at all, someone must make one final trip back in time to put the code on Fry's ass in the first place!
# Other    Other     Near-Death Star Landing Pad. The ships engines power up and they begin to move the universe in a flow-mo sequence lifted from
# Other    Other     Bailiffs! Get that innocent robot out of my courtroom!
# Other    Other     Yucks. I picked the wrong day to wear my new Crocses.
# Other    Other     Isn't it true, Mr. X, that you were slandering this innocent Mafioso to distract from your own felonious past?  Including the crime you made up yourself called burglarcenarsony?
# Fry    Other     Thanks. I wouldn't mind losing a few pounds though.
# Other    Amy     We did it, honey! Finally, we can have a legal, monogamous marriage, like everyone else!
# Bender    Other     Alright, when we get to Earth. But please don't invite too many people, I wanna keep it small.
# Other    Farnsworth     It seems to be working at only half-capacity, but I can fix it.
# Other    Leela     Oh, if only we hadn't flown penguins to Pluto and dumped oil on them, this might never have happened. Can't we stop them from multiplying?
# Other    Other     I was attacked by a vicious, motorised sled. The natives called it "The Abominable Snowmobile".
# Leela    Other     This Xmas Day session of court will come to order. The Honourable Judge Whitey presiding.
# Other    Fry     My God, I really can read minds. I have a superpower! There must be something great I can do with this.
# Amy    Zapp     The Spiderians, though weak and woman-like on the battlefield, are masters of the textile arts. Taste like king crab, by the way. Crazy bugs actually wove this tapestry of my heroic conquest while I was still killing them.
# Other    Other     It's true. I disguised myself as a Femputer so I could rule the Amazonians.
# 2783
# 3605

# %%
# clf_lr = LogisticRegression().fit(X_train, y_train)
# predicted_lr = clf_lr.predict(X_test)
# print("Logistic Regression", np.mean(predicted_lr == y_test))

# %%
# clf = KNeighborsClassifier().fit(X_train, y_train)
# predicted = clf.predict(X_test)
# np.mean(predicted == y_test)

# %%
# clf = GradientBoostingClassifier().fit(X_train, y_train)
# predicted = clf.predict(X_test)
# np.mean(predicted == y_test)

# %%
# All of the above consolidated:


def contextual_ml(weight, min_len, num_chars):
    print(f'Weight: {weight}')
    
    df = pd.read_csv(f"futurama/{num_chars}ch_CSVs/{num_chars}ch_futurama_binary_{weight}.csv")
    
    mask = (df['Quotes'].str.len() >min_len)
    df = df.loc[mask]

    df2 = df[["Fry", "Bender", "Leela", "Farnsworth", "Hermes", "Zoidberg", "Amy", "Zapp", "Other"]]
    df_quotes = df["Quotes"].values.astype('U')

    count_vec = CountVectorizer(stop_words="english", analyzer='word', 
                                ngram_range=(1, 1), max_features=None)

    # Transforms the data into a bag of words
    count_quotes = count_vec.fit_transform(df_quotes)
    count_quotes.shape
    
#     tfidf params: smooth_idf=False, sublinear_tf=False, norm=None

    tf_transformer = TfidfTransformer(smooth_idf=False, sublinear_tf=False, norm=None)
    quote_train_tf = tf_transformer.fit_transform(X=count_quotes)
    quote_train_tf.toarray()

    df2_matrix = csr_matrix(df2.values)

    df2_matrix_combined = hstack([quote_train_tf,df2_matrix]).toarray()

    df2_final = pd.DataFrame(df2_matrix_combined)

    df2_final["Characters"] = df["Characters"]

    X = df2_matrix_combined
    y = df2_final["Characters"].values.astype('U')
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

    clf_nb = MultinomialNB().fit(X_train, y_train)
    predicted_nb = clf_nb.predict(X_test)
    score_nb = np.mean(predicted_nb == y_test)
    score_dict['nb'].append(score_nb)
    print("Naive Bayesian:______", np.mean(predicted_nb == y_test))

    clf_sgq = SGDClassifier().fit(X_train, y_train)
    predicted_sgd = clf_sgq.predict(X_test)
    score_sgd = np.mean(predicted_sgd == y_test)
    score_dict['sgd'].append(score_sgd)
    print("SGD:_________________", np.mean(predicted_sgd == y_test))

    clf_rf = RandomForestClassifier().fit(X_train, y_train)
    predicted_rf = clf_rf.predict(X_test)
    score_rf = np.mean(predicted_rf == y_test)
    score_dict['rf'].append(score_rf)
    print("Random Forest:_______", np.mean(predicted_rf == y_test))

    clf_lr = LogisticRegression().fit(X_train, y_train)
    predicted_lr = clf_lr.predict(X_test)
    score_lr = np.mean(predicted_lr == y_test)
    score_dict['lr'].append(score_lr)
    print("Logistic Regression:_", score_lr)
    
    score_dict['weight'].append(weight)

# %%
num_of_chars = 4

for i in range(50, 51, 10):
    print("min length: ", i)
    
#     score_dict = dict(
#                 weight =[],
#                 nb     =[],
#                 sgd    =[],
#                 rf     =[],
#                 lr     =[] )
    
    for j in range(97, 102):
#         j += 1
        contextual_ml(j, i, num_of_chars)

        
    loop_df = pd.DataFrame(score_dict)
    loop_df.to_csv('futurama/results/{}ch_result_min_len_{}.csv'.format(num_of_chars, i))
# Out:
# min length:  50
# Weight: 97
# Naive Bayesian:______ 0.2809917355371901
# SGD:_________________ 0.2720086237872799
# Random Forest:_______ 0.5084441250449155
# Logistic Regression:_ 0.4315486884656845
# Weight: 98
# Naive Bayesian:______ 0.2809917355371901
# SGD:_________________ 0.3147682357168523
# Random Forest:_______ 0.518505210204815
# Logistic Regression:_ 0.44843693855551564
# Weight: 99
# Naive Bayesian:______ 0.2809917355371901
# SGD:_________________ 0.2867409270571326
# Random Forest:_______ 0.50700682716493
# Logistic Regression:_ 0.43765720445562345
# Weight: 100
# Naive Bayesian:______ 0.2813510600071865
# SGD:_________________ 0.4725116780452749
# Random Forest:_______ 0.5034135824649658
# Logistic Regression:_ 0.4477182896155228
# Weight: 101
# Naive Bayesian:______ 0.2813510600071865
# SGD:_________________ 0.5641394178943586
# Random Forest:_______ 0.5044915558749551
# Logistic Regression:_ 0.43837585339561624

# %%
print("Index: ", score_list_nb.index(max(score_list_nb)))
print("Max:   ", max(score_list_nb))
print("Avg:   ", np.mean(score_list_nb))
# Out:
# Index:  17
# Max:    0.2883793237465993
# Avg:    0.27407272297291946

# %%
print("Index: ", score_list_sgd.index(max(score_list_sgd)))
print("Max:   ", max(score_list_sgd))
print("Avg:   ", np.mean(score_list_sgd))
# Out:
# Index:  15
# Max:    0.5549941702293043
# Avg:    0.38091886408524206

# %%
print("Index: ", score_list_rf.index(max(score_list_rf)))
print("Max:   ", max(score_list_rf))
print("Avg:   ", np.mean(score_list_rf))
# Out:
# Index:  16
# Max:    0.567431014380101
# Avg:    0.5160865661910439

# %%
print("Index: ", score_list_lr.index(max(score_list_lr)))
print("Max:   ", max(score_list_lr))
print("Avg:   ", np.mean(score_list_lr))
# Out:
# Index:  17
# Max:    0.491255343956471
# Avg:    0.4335231994043838

# %%
# All of the above consolidated:


def contextual_ml2(weight, min_len, num_chars):
    print(f'Weight: {weight}')
    
    df = pd.read_csv(f"futurama/{num_chars}ch_futurama_binary_{weight}.csv")
    
    mask = (df['Quotes'].str.len() >min_len)
    df = df.loc[mask]

    df2 = df[["Fry", "Bender", "Leela", "Farnsworth", "Hermes", "Zoidberg", "Amy", "Zapp", "Other"]]
    df_quotes = df["Quotes"].values.astype('U')

    count_vec = CountVectorizer(stop_words="english", analyzer='word', 
                                ngram_range=(1, 1), max_features=None)

    # Transforms the data into a bag of words
    count_quotes = count_vec.fit_transform(df_quotes)
    count_quotes.shape
    
#     tfidf params: smooth_idf=False, sublinear_tf=False, norm=None

#     tf_transformer = TfidfTransformer(smooth_idf=False, sublinear_tf=False, norm=None)
#     quote_train_tf = tf_transformer.fit_transform(X=count_quotes)
#     quote_train_tf.toarray()

    df2_matrix = csr_matrix(df2.values)

    df2_matrix_combined = hstack([count_quotes,df2_matrix]).toarray()

    df2_final = pd.DataFrame(df2_matrix_combined)

    df2_final["Characters"] = df["Characters"]

    X = df2_matrix_combined
    y = df2_final["Characters"].values.astype('U')
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

    clf_nb = MultinomialNB().fit(X_train, y_train)
    predicted_nb = clf_nb.predict(X_test)
    score_nb = np.mean(predicted_nb == y_test)
    score_list_nb.append(score_nb)
    print("Naive Bayesian:______", np.mean(predicted_nb == y_test))

    clf_sgq = SGDClassifier().fit(X_train, y_train)
    predicted_sgd = clf_sgq.predict(X_test)
    score_sgd = np.mean(predicted_sgd == y_test)
    score_list_sgd.append(score_sgd)
    print("SGD:_________________", np.mean(predicted_sgd == y_test))

    clf_rf = RandomForestClassifier().fit(X_train, y_train)
    predicted_rf = clf_rf.predict(X_test)
    score_rf = np.mean(predicted_rf == y_test)
    score_list_rf.append(score_rf)
    print("Random Forest:_______", np.mean(predicted_rf == y_test))

    clf_lr = LogisticRegression().fit(X_train, y_train)
    predicted_lr = clf_lr.predict(X_test)
    score_lr = np.mean(predicted_lr == y_test)
    score_list_lr.append(score_lr)
    print("Logistic Regression:_", score_lr)

# %%
score_list_nb2 = []
score_list_sgd2 = []
score_list_rf2 = []
score_list_lr2 = []

for i in range(10, 51, 10):
    print("min length: ", i)
    
    for j in range(0, 55, 10):
        j += 1
        contextual_ml(j, i, 8)
# Out:
# min length:  10
# Weight: 1
# Naive Bayesian:  0.16166201117318435
# SGD:  0.1895949720670391
# Random Forest:  0.23550977653631286
# Logistic Regression 0.22119413407821228
# Weight: 11
# Naive Bayesian:  0.16934357541899442
# SGD:  0.18261173184357543
# Random Forest:  0.23533519553072627
# Logistic Regression 0.22136871508379888
# Weight: 21
# Naive Bayesian:  0.17108938547486033
# SGD:  0.16131284916201116
# Random Forest:  0.2431913407821229
# Logistic Regression 0.22206703910614525
# Weight: 31
# Naive Bayesian:  0.16847067039106145
# SGD:  0.21386173184357543
# Random Forest:  0.23830307262569833
# Logistic Regression 0.2210195530726257
# Weight: 41
# Naive Bayesian:  0.16777234636871508
# SGD:  0.26222067039106145
# Random Forest:  0.236731843575419
# Logistic Regression 0.2208449720670391
# Weight: 51
# Naive Bayesian:  0.16567737430167598
# SGD:  0.09427374301675978
# Random Forest:  0.23289106145251395
# Logistic Regression 0.22416201117318435
# min length:  20
# Weight: 1
# Naive Bayesian:  0.15129301567908776
# SGD:  0.1962940338016697
# Random Forest:  0.23131745062105477
# Logistic Regression 0.19853390348197922
# Weight: 11
# Naive Bayesian:  0.16208511504785175
# SGD:  0.13581755243331298
# Random Forest:  0.2250050906129098
# Logistic Regression 0.2056607615556913
# Weight: 21
# Naive Bayesian:  0.16065974343310935
# SGD:  0.24984728161270617
# Random Forest:  0.23070657707187944
# Logistic Regression 0.20667888413765018
# Weight: 31
# Naive Bayesian:  0.16208511504785175
# SGD:  0.15577275503970678
# Random Forest:  0.22520871512930157
# Logistic Regression 0.20606801058847485
# Weight: 41
# Naive Bayesian:  0.16045611891671757
# SGD:  0.1394827937283649
# Random Forest:  0.2333536957849725
# Logistic Regression 0.21054774994909387
# Weight: 51
# Naive Bayesian:  0.1610669924658929
# SGD:  0.1940541641213602
# Random Forest:  0.2180818570555895
# Logistic Regression 0.20749338220321728
# min length:  30
# Weight: 1
# Naive Bayesian:  0.17144256674014205
# SGD:  0.24687729610580456
# Random Forest:  0.3014939995101641
# Logistic Regression 0.25544942444281166
# Weight: 11
# Naive Bayesian:  0.18956649522409993
# SGD:  0.19397501836884642
# Random Forest:  0.2990448199853049
# Logistic Regression 0.2601028655400441
# Weight: 21
# Naive Bayesian:  0.1920156747489591
# SGD:  0.11168258633357825
# Random Forest:  0.2904726916482978
# Logistic Regression 0.26083761939750183
# Weight: 31
# Naive Bayesian:  0.1905461670340436
# SGD:  0.30933137398971344
# Random Forest:  0.29537105069801617
# Logistic Regression 0.26108253734998776
# Weight: 41
# Naive Bayesian:  0.19128092089150134
# SGD:  0.2890031839333823
# Random Forest:  0.29684055841293167
# Logistic Regression 0.26034778349253
# Weight: 51
# Naive Bayesian:  0.18981141317658584
# SGD:  0.3095762919421994
# Random Forest:  0.2916972814107274
# Logistic Regression 0.26083761939750183
# min length:  40
# Weight: 1
# Naive Bayesian:  0.20328358208955224
# SGD:  0.31791044776119404
# Random Forest:  0.4208955223880597
# Logistic Regression 0.3319402985074627
# Weight: 11
# Naive Bayesian:  0.21970149253731344
# SGD:  0.41492537313432837
# Random Forest:  0.4217910447761194
# Logistic Regression 0.32925373134328356
# Weight: 21
# Naive Bayesian:  0.2208955223880597
# SGD:  0.21164179104477612
# Random Forest:  0.4256716417910448
# Logistic Regression 0.3295522388059702
# Weight: 31
# Naive Bayesian:  0.2253731343283582
# SGD:  0.3805970149253731
# Random Forest:  0.42388059701492536
# Logistic Regression 0.32925373134328356
# Weight: 41
# Naive Bayesian:  0.2253731343283582
# SGD:  0.11432835820895522
# Random Forest:  0.41582089552238805
# Logistic Regression 0.328955223880597
# Weight: 51
# Naive Bayesian:  0.2244776119402985
# SGD:  0.4635820895522388
# Random Forest:  0.4262686567164179
# Logistic Regression 0.32985074626865674
# min length:  50
# Weight: 1
# Naive Bayesian:  0.23643550125763566
# SGD:  0.40280273086597196
# Random Forest:  0.5156306144448437
# Logistic Regression 0.42651814588573483
# Weight: 11
# Naive Bayesian:  0.2597915918074021
# SGD:  0.4800574919151994
# Random Forest:  0.5224577793747754
# Logistic Regression 0.4369385555156306
# Weight: 21
# Naive Bayesian:  0.2691340280273087
# SGD:  0.2971613366870284
# Random Forest:  0.5267696730147323
# Logistic Regression 0.44915558749550843
# Weight: 31
# Naive Bayesian:  0.2738052461372619
# SGD:  0.34746676248652536
# Random Forest:  0.5159899389148401
# Logistic Regression 0.45023356090549765
# Weight: 41
# Naive Bayesian:  0.2766798418972332
# SGD:  0.5379087315846209
# Random Forest:  0.518505210204815
# Logistic Regression 0.448796263025512
# Weight: 51
# Naive Bayesian:  0.27883578871721165
# SGD:  0.5102407473948976
# Random Forest:  0.5145526410348544
# Logistic Regression 0.43190801293568093

# %%
print("Index: ", score_list_nb.index(max(score_list_nb)))
print("Max:   ", max(score_list_nb))
print("Avg:   ", np.mean(score_list_nb))
# Out:
# Index:  29
# Max:    0.27883578871721165
# Avg:    0.20000370589967756

# %%
print("Index: ", score_list_sgd.index(max(score_list_sgd)))
print("Max:   ", max(score_list_sgd))
print("Avg:   ", np.mean(score_list_sgd))
# Out:
# Index:  27
# Max:    0.5551563061444484
# Avg:    0.27677437419356843

# %%
print("Index: ", score_list_rf.index(max(score_list_rf)))
print("Max:   ", max(score_list_rf))
print("Avg:   ", np.mean(score_list_rf))
# Out:
# Index:  56
# Max:    0.5267696730147323
# Avg:    0.33967600924603786

# %%
print("Index: ", score_list_lr.index(max(score_list_lr)))
print("Max:   ", max(score_list_lr))
print("Avg:   ", np.mean(score_list_lr))
# Out:
# Index:  27
# Max:    0.45023356090549765
# Avg:    0.2915551020676768

# %%
len(df)
# Out:
# 25550

# %%
for i in range(0, 51, 10):
    mask = (df['Quotes'].str.len() >i)
    masked_df = df.loc[mask]
    
    print('--------------------')
    print(i, "  ", len(masked_df))
    print()
    print(masked_df["Characters"].value_counts())
    print('--------------------')
    print()
# Out:
# --------------------
# 0    25550
#
# Other         9754
# Fry           4014
# Bender        3734
# Leela         3194
# Farnsworth    1558
# Zoidberg       992
# Amy            933
# Hermes         867
# Zapp           504
# Name: Characters, dtype: int64
# --------------------
#
# --------------------
# 10    22910
#
# Other         8846
# Fry           3538
# Bender        3334
# Leela         2883
# Farnsworth    1427
# Zoidberg       858
# Hermes         783
# Amy            774
# Zapp           467
# Name: Characters, dtype: int64
# --------------------
#
# --------------------
# 20    19641
#
# Other         7622
# Fry           2962
# Bender        2809
# Leela         2488
# Farnsworth    1292
# Zoidberg       736
# Hermes         681
# Amy            637
# Zapp           414
# Name: Characters, dtype: int64
# --------------------
#
# --------------------
# 30    16332
#
# Other         6418
# Fry           2408
# Bender        2305
# Leela         2038
# Farnsworth    1154
# Zoidberg       588
# Hermes         562
# Amy            491
# Zapp           368
# Name: Characters, dtype: int64
# --------------------
#
# --------------------
# 40    13397
#
# Other         5324
# Fry           1909
# Bender        1854
# Leela         1669
# Farnsworth    1006
# Zoidberg       474
# Hermes         463
# Amy            371
# Zapp           327
# Name: Characters, dtype: int64
# --------------------
#
# --------------------
# 50    11131
#
# Other         4479
# Fry           1533
# Bender        1490
# Leela         1369
# Farnsworth     903
# Hermes         385
# Zoidberg       378
# Zapp           300
# Amy            294
# Name: Characters, dtype: int64
# --------------------
