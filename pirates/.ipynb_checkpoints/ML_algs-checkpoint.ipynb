# %%
import pandas as pd
import numpy as np
import nltk


from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv('4ch_pirates.csv')
del df["Unnamed: 0"]

df.head(3)
# Out:
#   Characters                              Quotes
# 0  Elizabeth                          Yes, yes!\
# 1  Elizabeth                Oh, it?s beautiful!\
# 2  Elizabeth  May I inquire as to the occasion?\

# %%
df = df.sort_values("Characters")

# %%
def corpus_builder(dataframe):
    
    num_of_char = len(dataframe["Characters"].unique())
    
    X = df["Quotes"].values.astype('U')
    y = df["Characters"].values.astype('U')
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=4)
    
    df_train = pd.DataFrame({"Quotes" : X_train, "Characters" : y_train})
    df_test = pd.DataFrame({"Quotes" : X_test, "Characters" : y_test})
    
    
    
    corpi_train_quotes = []
    corpi_train_chars = []

    corpi_test_quotes = []
    corpi_test_chars = []

    
    
    for i in range(num_of_char):
        loop_char = dataframe["Characters"].unique()[i]
        corpi_train_chars.append(loop_char)
        corpi_test_chars.append(loop_char)
        
        loop_corpus_train = df_train.loc[df_train.Characters == loop_char]
        loop_corpus_test = df_test[df.Characters == loop_char]
        
        loop_corpi_train_list = []
        loop_corpi_test_list = []

        
        for j in loop_corpus_train["Quotes"]:
            loop_corpi_train_list.append(j)
            
        for k in loop_corpus_test["Quotes"]:
            loop_corpi_test_list.append(k)
            
        loop_corpus_train = " ".join(loop_corpi_train_list)
        loop_corpus_test = " ".join(loop_corpi_test_list)
        
        corpi_train_quotes.append(loop_corpus_train)
        corpi_test_quotes.append(loop_corpus_test)
        
    corpi_train_quotes = np.asarray(corpi_train_quotes)
    corpi_train_chars = np.asarray(corpi_train_chars)
    corpi_test_quotes = np.asarray(corpi_test_quotes)
    corpi_test_chars = np.asarray(corpi_test_chars)
        
    
    return corpi_train_quotes, corpi_train_chars, corpi_test_quotes, corpi_test_chars

# %%
a, b, c, d = corpus_builder(df)
# Out:
# C:\Users\timot\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:29: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
# Out:
# 'Pah Id have won a lot of money too if I still had my lucky sevenleaf clover Plus Id still have my hair Why does everything I date run away  I love Leela always and forever  And if I loved Robot Leela too That clover helped my ratfink brother steal my dream of going into space Now Ill never get there So this things gonna destroy the whole city  What the heck is it Allow me mlady  Shall we go atrousering Im your dear old Uncle Fry Episode 10 Balance of Terror Thus sayeth the tentacle Verily thou shalt rejoice in the house of the tentacle I heard that one time you singlehandedly defeated a horde of rampaging somethings in the somethingsomethingsystem You can All you have to do is wake up Come on Leela Step your big boot down on the gas pedal Does the word Maltese mean anything to you 3000 Yes Im still in the future Life is wonderful  Wait What are you doing with my stuff Uh Leela how you gonna meet your folks tomorrow Weve already scheduled the Zookeeper for a 9am foiling at the museum I think I saw a mermaid Nope Not vaccinated either Besides its not like one vote ever made a difference How did I do it How did I get Leela to love me Ive got to figure it out No thanks Thats robot food You know 1966 79 episodes about 30 good ones Hey gimmie a break What do you do with it Oh its Benders apartment He put in carpeting yesterday so now my head hits the ceiling Hey do you realise youre standing at a weird angle  Now youre OK Friendship then Ill sell Planet Express for you Leela Stop bonding and lets go I got jelly in my underpants Oh my God Oh my God Although actually it was sort of obvious No thanks I make my own No its a mobile apartment with no rent Whos the Zapp Brannigan All right We can go home I I dont understand You made me go in the freezer tube Uh  IIve got talking hump syndrome So what do you nerds want Yeah If you rule out every guy with a lizard tongue or a low IQ or an explosive violent temper of course youre gonna be lonely Um what color is my shirt Oh that reminds me  Its time to twit my hourly twupdate  Scratchin my underarm fungus  Lookin for love  Send The day I got frozen What about it I know but I forgive you Its some guy wearing a Leela costume Get him Come on boy Come back to life Pfff Those things dont rhyme Whos playing pin the tail on the moon maggot Where the hell are we hell Certainly yes us uhhuh sir Weve gotta bring back the kind of Xmas I remember Not beautiful enough A swell gal like you deserves better However huge it might be Look it has Slurm Loco Its the extremeiest One bucket o doublefriend triplesalted boneless sheep tots please Looks like its full of dig dogs Leela No  Listen to me you dont want to lie in bed like a vegetable and do nothing the rest of your life Ive tried it Bedsores hurt I couldnt help it She loved me because of the part of me thats a slob and I loved her because of the part of me thats desperate One year later I gave Leela a diamond scrunchie and we were married Like my parents Oh wait that was hitting No its an old Volkswagen van  Hey Mister Mind if I take this old van That guy who used to bend things You know Not till I get my 600 quatloos Ive been there My folks were always on me to groom myself and wear underpants What am I the Pope Everyone out of my body or the brain gets it I know Big Vinnie said he was giving me the kiss of death but I still think he was gay Hey yeah I used to spit at stuff back in the 20th century Ah its cool how we sort of think exactly alike and junk Hello Has anyone out there seen Bender And with a little more luck from my sevenleaf clover I might get sick enough to miss the whole semester No its about you and me and   Pop a Poppler in your mouth\r\nWhen you come to Fishy Joes\r\nWhat theyre made of is a mystery\r\nWhere they come from no one knows\r\nYou can pick em\r\nYou can lick em\r\nYou can chew em\r\nYou can stick em\r\nIf you promise not to sue us\r\nYou can shove one up your nose Not this time No matter what happens Ill swear I be there Hey ...

# %%
X = df["Quotes"].values.astype('U')
y = df["Characters"].values.astype('U')
print(X.shape, y.shape)
# Out:
# (1053,) (1053,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train
# Out:
# array(['I don’t know what you mean.',
#        'It’s not a fate you had to choose for yourself either.', '\\',
#        '\\', '\\', "And really bad eggs?drink up, me 'earties, yo ho.\\",
#        'My father is on that ship. If we can outrun her, we can take her. We should turn and fight.',
#        'Properly?', 'Oh.', 'There!', 'Time to go.', 'That is too bold.\\',
#        'The property you want that he possesses.',
#        'Elizabeth! Elizabeth! Will you marry me?', 'Will.\\',
#        'Doesnâ€™t matter now. The Pearl’s gone… along with its Captain.',
#        '\\',
#        'It wasn?t your blood they needed. It was my father?s blood?my blood?the blood of a pirate.\\',
#        'Keep us steady now. Now!\\', 'It does me.',
#        'Jack. I know Will came to find you, where is he?', 'Excuse me.\\',
#        'Yes, he did say something about a chest.',
#        'And you have chosen yours. We will fight, and you will die.',
#        'I can?t move it.  Will!\\', 'They’ll know you helped me.',
#        'That makes you...chart man!',
#        'If an adversary demands parley you can do them no harm until the parley is complete.\\',
#        'You are familiar with that ship&#160;? the Black Pearl?\\',
#        'Father! Commodore, do you really intend to kill my rescuer? \\',
#        'Take her out or she’ll overbear us!', 'Like that.\\',
#        'Not more pirates.\\', 'Technically, I –',
#        'To stations! All hands, to stations! Hard to port, gather way!',
#        'Gentlemen, what do keys do?', 'That?s very interesting.\\',
#        'Elizabeth&#160;?Turner. I?m a maid in the Governor?s household.  \\',
#        'No!',
#        'It?s what you?ve been searching for. I recognized the ship. I saw it eight years ago on the crossing from England .\\',
#        'And made you captain? They’re just giving the bloody title away now.',
#        'Come on men, it’ll take all of us to Crew the Black Pearl!',
#        'Tia Dalma.', 'The Kraken. To arms!',
#        'Oh, don’t be absurd, I trust him, that’s all.',
#        'Yes, there it is. Why is it there? It’s much larger up close.',
#        'I’m not sorry.', 'It?s difficult to say.\\', 'Not probable.\\',
#        'Maybe. Why?', 'I can get you out of here.\\', 'nan',
#        'Not to the boats? \\', 'I cut down anyone in my path.',
#        'Your funeral.\\',
#        'I have been to the Isla de Muerta, I have seen the treasure myself. There is something you need to know.',
#        'This is madness.',
#        "Not just the Spanish Main , love. The entire ocean. The entire wo?ld. Wherever we want to go, we?ll go. That?s what a ship is, you know. It?s not just a keel and a hull and a deck and sails that's what a ship needs but what a ship is?what the Black Pearl really is?is freedom.\\",
#        'I always liked you.\\', 'No! no! no! no!',
#        'Fire!  It’ll be back. We have to get off the ship.',
#        'Complications arose, ensued, were overcome.',
#        'Yes, Will is alive. And he wants to help you.',
#        'Have not, slander and calumny! I have only ever embraced that oldest and noblest of pirate traditions. I submit here and now, that is what we all must do, we must fight... to run away.',
#        'That doesn’t sound like me.  Shall we just call it square, then?',
#        'I?d die for her.\\', 'Oh, that key.', 'Elizabeth&#160;!\\',
#        'Ah, a familiar face.', 'I know exactly what you mean, love. \\',
#        'Ready on the guns!',
#        'I shall. A craftsman is always pleased to hear his work is appreciated.\\',
#        'Ah. So it’s you, then. He shanghaied you into service, eh?',
#        'When?s that? When it?s of greatest profit to you?\\',
#        'Ah. The dark side of ambition.', 'Very well. I?ll drop it. \\',
#        'Yes to the first, yes to the second, but only as so far as we keep to the shallows as much as possible.',
#        'The key.', 'Bootstrap?', 'She?s not what they?re after.\\',
#        'No. \\', 'Pirate. Here. Let me. \\', 'He’s taking over the seas.',
#        'These are not going to Jack.',
#        'You’re right. Then what shall we die for?  You will listen to me. Listen! The brethren will still be looking here to us, to the Black Pearl to lead, and what will they see? Frightened bilge rats aboard a derelict ship? No! They will see free men, and freedom. And what the enemy will see is the flash of our cannons, they will hear the ring of our swords and they will know what we can do! By the sweat of our brows, and the strength of our backs, and the courage of our hearts... gentlemen, hoist the colors!',
#        'This is the fastest ship in the Caribbean .\\',
#        'I hadn’t finished that. You will free my father.  And you will guarantee Elizabeth’s safety, along with my own.',
#        'You’ve not told him? We rescued Jack from the locker along with the Black Pearl.',
#        'As you command.', 'We?re catching up.\\', 'I do.',
#        'It’s the sunrise.', 'Where’s the rest of the Crew?',
#        'I’ve sworn no oath.', 'So you get both Jack and the Black Pearl.',
#        'Maybe he really does know what he’s doing.',
#        'Why not? We are very much alike you and I. I and you… us.',
#        'Good day, sir. I have your order. \\',
#        'Then release me, you have your trinket; I?m of no further value to you.\\',
#        'I think it’s bad luck for the groom to see the bride before the wedding.',
#        'Have you heard anything from Will?',
#        'No. I expect to leave you standing on some beach with absolutely no name at all, watching me sail away on my ship and then I?ll shout the name back to you. Savvy?\\',
#        'Whose side is Jack on?\\', 'Captain Sparrow?',
#        'It’s me front I’m worried about.', 'He’s the captain.',
#        'Except for a sense of honor and decency and a moral center. And personal hygiene.',
#        'If he’s not with you, and he’s not with us...who’s he with?',
#        'Curiosity. You’re going to want it – a chance to be admired – and gain the rewards that follow. You won’t be able to resist. You’re going to want to know what it tastes like.',
#        'Elizabeth Swann, do you take me to be your husband?',
#        'Trifles. You Will come over to my side, I know it.',
#        'What has the world done to you?',
#        'You’ll have the chance to do something… something courageous. And when you, you’ll discover something. That you’re a good man.',
#        'nan', 'I know that. I know where I am, and don’t think I don’t.',
#        'He was a good man.', 'O?course it does.  Satisfied?\\',
#        'We?re shallow on the draft, right?\\',
#        'A fair trial for Will ends in a hanging.', 'What are YOU doing?',
#        'Thank you.\\', 'Now up is down.',
#        'Captain Barbossa , I am here to negotiate the cessation of hostilities against Port Royal .\\',
#        'That?s why I know what Barbossa is up to. All I need is a crew.\\',
#        'You knew William Turner&#160;?\\', 'Me?', 'I promise.',
#        'Every word, love. And what you want most in this world…  is to find the chest of Davy Jones, is it not?',
#        'nan',
#        'Miss Swann , if you?d be so kind. Come, come, dear. We don?t have all day. Now if you?d be very kind.  Easy on the goods, darling.\\',
#        'Keep a weather eye on the horizon.',
#        'He was a bloody pirate, a scallywag.\\',
#        'Will strikes a deal for these and upholds it with honor, yet you are the one standing here with the prize.  As if I could be bought for such a low price.',
#        'Where?s Elizabeth&#160;?\\',
#        'Have you not met Will Turner? He’s noble, heroic, a terrific soprano. Worth at least four, maybe three and a half. And did I happen to mention… he’s in love. With a girl. Due to be married. Betrothed. Dividing him from her and her from him would only be half as cruel as actually allowing them to be joined in holy matrimony. Aye?',
#        'Hard to starboard!', 'Uh, Mr. Gibbs?',
#        'Close your eyes and pretend it’s all a bad dream. That’s how I get by.',
#        'King.', 'Yes, yes!\\', 'What are the charges?', 'nan',
#        'Just hear me out, mate. You order your men to row out to the Dauntless. They do what they do best. Robert&#160;?s your Uncle, Fannie&#160;?s your Aunt, there you are with two ships. The makings of your very own fleet.&#160;?Course you?ll take the grandest as your flagship, and who?s to argue? But what of the Pearl&#160;? Name me Captain, I?ll sail under your colors, I?ll give you ten percent of me plunder and you get to introduce yourself as?Commodore Barbossa. Savvy?\\',
#        'There has been a perpetual and virulent lack of discipline aboard my vessel! Why is that, sir?',
#        'Persuasion.', 'He’s a better man than you give him credit for.',
#        'That’s not part of the game, is it?  You can still walk away.',
#        'Barbossa! Now!', 'What about Jack? I won’t leave without him.',
#        'That one. \\',
#        'Thank you, Commodore, for getting us ready to make way. We?d have had a hard time of it by ourselves.\\',
#        'Her?', 'Beg pardon?', 'No. Persuade me.',
#        'You murdered my father.',
#        'Ask him where it is. Make a deal with him. He could lead us to it.\\',
#        'I already have the key.', 'Barbossa.\\', 'Captain Jack Sparrow.',
#        'To what point and purpose, young missy? The Black Pearl is gone and unless you have a rudder and a lot of sails hidden in that bodice&#160;? unlikely - young Mr. Turner will be dead long before you can reach him.\\',
#        'Mr. Sparrow.', 'That debt was paid, mate, with  help.',
#        'Parley!\\', 'But why is the rum gone?\\',
#        'Good man. Good pirate. I swear you look just like him.\\',
#        'A wedding! I love weddings?drinks all around!  I know.&#160;?Clap him in irons,? right?\\',
#        'nan', 'Or you could surrender.\\',
#        'Ah, fortunately I know how to counter it. The man who did the waking buys, the man who was sleeping, a drink. The man who was sleeping drinks it while listening to a proposition from the man who did the waking.\\',
#        'At the ready!',
#        'Guard the boat; mind the tides… don’t touch my dirt.',
#        'It’ll attack the starboard, I’ve seen it before. Roll out the cannons and hold for my signal.',
#        'Put it away, son. It?s not worth you getting beat again.\\',
#        'I did not. I didn’t know where the key was. But now we do. So, all that’s left is to climb aboard the Flying Dutchman, grab the key, you go back to Port Royal and save your bonnie lass, aye?',
#        'What’s this for?', 'Well, you?ve proved they?re mad.\\',
#        'Will you be saving her then?\\', 'Belay!', 'Elizabeth .\\',
#        'You want me to find this.', 'But you’re his father.', 'nan',
#        'Friendly?', 'You?ll get another one.\\',
#        'Meaning William Turner, Captain Sparrow.', "It'll linger.\\",
#        'What one? That one?! Aye, that one. What say you?\\',
#        'Well, women in London must?ve learned not to breathe.\\',
#        'Easy boys.',
#        'I do that quite a lot, yet people are still surprised.',
#        'Then load the rum!', 'Well, there is a chest.', 'Will.\\',
#        'He’ll cover our escape and meet us at Shipwreck Cove.',
#        'What do you know of it?', 'Your turn.\\',
#        'That was for the smell.\\', 'Yes, I’m Elizabeth.', '\\',
#        'Because I was afraid that you were a pirate. That would have been awful.\\',
#        'I don?t know. \\', 'We’re not free yet, though.',
#        'It?s not true. He was a merchant sailor. A good, respectable man who obeyed the law.\\',
#        'Mr. Gibbs, any particular reason why my ship is gone?',
#        'Is the… jar of dirt going to help?',
#        'Really?  And by the way, no, I’ve never actually met Pisaro, but I love his pies. And all of this pales into utter insignificance in light of the fact that my ship is once again, gone, savvy?',
#        'You’ve got to tell me what’s happening.',
#        'Human hair?from my back. Let go of the anchor!\\',
#        'I knew you?d warm up to me. Commodore Norrington, my effects, please, and my hat. Commodore! Elizabeth . It is Elizabeth isn?t it?\\',
#        'nan', 'Will Turner .\\', 'That’s why I brought this!',
#        'Pirate!  Move away.\\', 'Mr Gibbs!',
#        'What say you about the condition of this tack line?', 'Hold on!',
#        'No. You want you to find this. Because the finding of this, finds you incapacitorially finding and/or locating in your discovering the detecting of a way to save your dolly belle ol’ what’s her face. Savvy?',
#        'Might I point out that we are still short one pirate lord, and I’m content as a cucumber to wait until Sao Feng joins us.',
#        'So he had no choice. He’s a captive there as much as the rest of us.',
#        'Well, then, I confess, it is my intention to commandeer one of these ships, pick up a crew in Tortuga,  raid, pillage, plunder and otherwise pilfer my weasely black guts out!\\',
#        'And this is what you’ve arrived at? Lead Beckett to Shipwreck Cove so as to gain his trust, accomplish your own ends? It’s like you don’t know me at all, mate. And how does your dearly beloved feel about this?  Ah, you’ve not seen fit to trust her with it.',
#        'I have not!', 'I want this.', 'nan',
#        'Why should I sail with any of you? Four of you have tried to kill me in the past, one of you succeeded.',
#        'Good one. I just came to get me effects. Admirable though it may be, why are you here when you could be elsewhere?',
#        'Captain, Captain Jack Sparrow .\\',
#        'You threatened Miss Swann .\\', 'Bootstrap. Bill Turner?',
#        'A chest of unknown size and origin.',
#        'Captain Barbossa, we need you at the helm.',
#        'She’s falling behind!', 'Fire!',
#        'And the crew&#160;? the crew are not to be harmed.\\',
#        'It was never about winning or losing.', 'Who?  You?',
#        'Where’s Sao Feng?', 'Well, go on, go get them! Helalla!', 'Ah!',
#        'How do we find it?', 'She can hold a bit longer.\\',
#        'What d?ye say to three shillings? and we forget the name?\\',
#        'Prepare to broadside!',
#        'Pretty speech from a captor. But words whispered through prison bars lose their charm.',
#        'You seem very certain.',
#        'Just how many souls, do you think, my soul is worth?', 'Shiny?',
#        'Fine. Well, I suppose if it is worthless then there?s no point in me keeping it. \\',
#        'You can keep doing that forever, the dog is never going to move.\\',
#        'That?s the second time I?ve had to watch that man sail away with my ship.\\',
#        'You have no idea.', 'Welcome to the Caribbean , love. \\',
#        'Is that how you’re all feeling, then? Perhaps dear ol’ Jack is not serving your best interests as Captain?',
#        'Hmm.',
#        'I love those moments. I like to wave at them as they pass by.',
#        'A truly discomforting notion, love.', 'nan', 'nan', 'Ah.', 'nan',
#        'No cause is lost if there is but one fool left to fight for it.',
#        'Technically...',
#        'Come on. Snap to and make sail, you know how this works. Oi, oi!',
#        'I’m not going to eat you.', '\\', 'Elizabeth Swann.',
#        'And if there are Crewmen?', 'nan',
#        'Hurry. Someone will have heard that.\\', 'nan', 'We',
#        'On our stern and gaining!', 'We fight!', 'Guard the chest.',
#        'Don’t leave me! I won’t leave you!', 'About me?\\',
#        'I didn’t say port. I said land, any land.',
#        'I’ve had more than enough experience dealing with pirates!',
#        'It?s Miss Swann .\\', 'No, that one I deserved.\\',
#        'Tell them to let me down.',
#        'Well that’s more than less than unhelpful.', 'Then what is?',
#        'You know these clothes do not flatter you at all. It should be a dress or nothing. I happen to have no dress in my cabin.',
#        'Elizabeth Swann.', 'Fire!',
#        'There’s no place left for Sao Feng to cower. Do you think he will honor the call?',
#        'Let us examine that claim for a moment, former Commodore, shall we? Who was it that at the very moment you had a notorious pirate safely behind bars saw fit to free said pirate and take your dearly beloved all to hisself… aye? So whose fault is it really that you’ve ended up a rum-pot deckhand what takes orders from pirates?',
#        'Don?t do anything stupid.\\',
#        'If you were waiting for the opportune moment?that was it. Now, if you?ll be so kind, I?d be much obliged if you?d drop me off my ship.\\',
#        'At least once more, Miss Swann , as always.\\',
#        'Elizabeth! They’re pirates!',
#        "Me? I'm dishonest. And a dishonest man you can always trust to be dishonest. Honestly. It's the honest ones you want to watch out for, because you can never predict when they're going to do something incredibly? stupid. \\",
#        'Barbossa, you can’t release her.',
#        'Will, I?m so sorry, please forgive me. \\',
#        'What? He failed to mention that.\\', 'Why ask', 'Tortuga.',
#        'I?m sorry, it?s just - it?s such a pretty boat.',
#        'I don’t know.  You look beautiful.',
#        'If there was anything to be done to bring him back, Elizabeth…',
#        'Sao Feng is dead. He fell to the Flying Dutchman.',
#        'I don’t see Jack, I don’t see anyone.', '\\', 'nan',
#        'Jack, the letters, give them back.',
#        'I’m losing her Jack. Every step I take for my father is a step away from Elizabeth.',
#        'That would be the French.\\',
#        'You can keep Barbossa, the belligerent homunculus and his friend with the wooden eye both, and Turner... especially Turner. The rest go with me aboard the Pearl, and I will lead you to Shipwreck Cove, where I will hand you the pirates and you will NOT hand me to Jones. Bloody fair deal, don’t you think?',
#        'Aye.\\', 'That dress… where did you get it?',
#        'They haven?t seen you. Hide, and the first chance you get, run to the fort. \\',
#        'Listen. Our location has been betrayed. Jones is under the command of Lord Beckett, they’re on their way here.',
#        'Mr. Sparrow&#160;?I?m not entirely sure that I?ve had enough rum to allow that kind of talk.\\',
#        'You haven’t raised an alarm.',
#        'Why would he do this to us? If Jack is the chief –',
#        'Well, you may tell the captain that I am disinclined to acquiesce to his request.\\',
#        '\\', 'My ship, makes me captain.', 'Fool. Why did you do that?',
#        'Roll the cage!  Lift the cage!',
#        'Pirate?s Code. Any man that falls behind?is left behind.\\',
#        'Seeing as there?s two of us, a gentleman?would give us a pair of pistols.\\',
#        'Fire all! \\', 'A woman!',
#        'And whoever possesses that chest, possesses the leverage to command Jones to do whatever it is he or she wants. Including saving brave William from his grim fate.',
#        'Commandeer. We?re going to commandeer that ship. Nautical term. One question about your business, boy, or there?s no use going. This girl&#160;? how far are you willing to go to save her?\\',
#        'My father’s dead.',
#        'Yeah, I gave you payment. One soul to serve on your ship is already over there.',
#        'You do know Will taught me how to handle a sword.',
#        'No, you can’t be!',
#        'When I was a lad living in England , my mother raised me by herself. After she died, I came out here, looking for my father.\\',
#        'We?re going to steal the ship. That ship? \\',
#        'Why is Jack afraid of the open ocean?', 'You’ve doomed us all!',
#        'No.\\',
#        'You can fight!  Get off me! You are Sao Feng, the pirate lord of Singapore!',
#        'Tia Dalma. Calypso.  When the Brethren Court first imprisoned you, who was it that told them how? Who was it that betrayed you?',
#        'What did the bird say?!',
#        'I?d really rather hoped we were past all this.\\', '\\',
#        'I will accept the consequences of my actions.\\',
#        'Not yet. We wait for the opportune moment.\\',
#        'Never!  They took Miss Swann .\\',
#        'Mate, if you choose to lock your heart away, you’ll lose it for certain. If I may lend a machete to your intellectual thicket—avoid the choice altogether. Change the facts. Let someone else dispatch Jones.',
#        'And if I should choose not?',
#        'But I did bear it, didn’t I? I just didn’t know what it was. I thought...',
#        'Elizabeth goes free.\\', 'Elizabeth.', 'Move!',
#        '...would you have that era come to an end on your watch? The most notorious pirates from around the world are uniting against our enemy, and yet you sit here, cowering in your bath water!',
#        'Now, to be quite honest with you, there?s still a slight risk for those aboard the Dauntless which includes the future Mrs. Commodore .\\',
#        '\\', 'Pretty much. Time and tide, love.  Oi, what are you doing?',
#        'You don?t want to be doing that, mate.\\',
#        'Well, then I?d say it?s a very good thing I?m not a fool then, eh?\\',
#        'Here they come.\\',
#        'I’m not certain I can survive any more visits from old friends.',
#        'Bootstrap? Bill Turner?',
#        "Ah, well, then it would be a shame to put a black mark on your record. So, if you'll excuse me?  Do you think this wise, boy&#160;? crossing blades with a pirate?\\",
#        'Thank you.\\',
#        'To my great regret. But, never to late to learn, eh?',
#        'Scarlett&#160;!  Not sure I deserved that. Giselle! \\',
#        'How much do you know about Davy Jones?', 'Nothing.',
#        'Norrington took it to draw them off.', 'Fifteen.\\',
#        'I?m terribly sorry. I', '...me.',
#        'You agreed, the Black Pearl was to be mine.',
#        'Confirm what? You’ve told me nothing.',
#        'If it weren’t for these bars, I’d have you already.  I’ll wait for you.',
#        'So the Captain has the key.  Where is the key?',
#        'Because you happen to have a ship a and crew you don’t need?',
#        'Pirate or not this man saved my life.\\',
#        'How can we sail to an island that nobody can find with a compass that doesn?t work?\\',
#        'Ahh. Where?s dear William&#160;?\\', 'Yes, I know your son.',
#        'Well spoke, listen to the tool.',
#        'And the green flash happens at sunset, not sunrise.',
#        'What is it you want most?', 'It?s poisoned.\\', 'Will.',
#        'To the Black Pearl .  No! Not good! Stop! Not good! What are you doing? You burned all the food, the shade! The rum!\\',
#        'Do tell, dearie.', 'And in return?', 'We have our heading.',
#        'Keep telling yourself that, darlin’.  Once was quite enough.',
#        'Good day? &#160;? Elizabeth .\\', 'Is that so?\\',
#        'All hand?s to the boats!  Apologies. You give the orders.\\',
#        'She goes free. \\',
#        'We’ll have to try it. We can get away as it takes down the Pearl.',
#        'Mr. Gibbs, you may throw my hat if you like.',
#        'You know, for having such a bleak outlook on pirates you?re well on your way to becoming one. Sprung a man from jail, commandeered a ship of the Fleet, sailed with a buccaneer crew out of Tortuga &#160;?and you?re completely obsessed with treasure.\\',
#        'Not without my effects.\\', 'Oh, shut it.',
#        'I imagine… some of your Crew may have jumped ship there.',
#        "Ah. So that's the reason for all the?  \\",
#        'Inescapably clear.\\', 'Once every ten years.',
#        'Hoist the colors.', 'I have a ship.',
#        'Know what? Which side you chose?  Well now you do.',
#        'Where’s Jack?', 'Ah.',
#        'No.  We don’t have the key, we can’t open whatever it is we don’t have that it unlocks. So, what purpose would be served in finding whatever need be unlocked, which we don’t have, without first having found the key what unlocks it.',
#        'Sticks and stones, love. I saved your life, you save mine, we?re square. Gentlemen, m?lady, you will always remember this as the day that you almost caught Captain Jack Sparrow&#160;! \\',
#        'We’ll use the Black Pearl as a flagship to lead the attack.',
#        'I hardly believe in ghost stories anymore, Captain Barbossa .\\',
#        'UP IS DOWN. Well that’s just maddeningly unhelpful. Why are these things never clear?',
#        'A better one!\\', 'Good day, Mr. Turner .\\',
#        'Technically, I was only Captain for two years, then I was viciously mutinied upon.',
#        'You seem somewhat familiar. Have I threatened you before?\\',
#        'That?s not true. I am not obsessed with treasure.\\',
#        'I don’t have the face for tentacles. But immortal has to count for something, eh? Oh!',
#        'You’re a darling, mate. Send me back the boy, I’ll get started right off.',
#        'I need the Black Pearl to free my father.  You’re helping me to get it.',
#        'Over the edge and over again. Sunrise sets flash of green... Do you care to interpret, Captain Barbossa?',
#        'You know me?',
#        'Oh, yes.  But the company is infinitely better than last time, I think. The scenery has definitely improved.\\',
#        'Leave you people alone for a minute and look what’s happened, everything’s gone to pot.',
#        'Bravo, you escaped the brig even quicker than I expected. William, do you notice something? Or rather do you notice something that is not there to be noted?',
#        'I?m having a thought here, Barbossa. What say we run up a flag of truce? I scurry over to the Interceptor, and I negotiate the return of your medallion, eh? What say you to that?\\',
#        'I can?t breathe.\\',
#        'I need the Pearl to free my father. That’s the only reason I came on this voyage.',
#        'Well, we can’t just sit here and wait then, can we?',
#        'Never actually been one for tradition... Close haul her. Luff the sails and lay on iron!',
#        'Do you mind if we make a little side trip? I didn’t think so.',
#        "Well, then can't we lose them amongst those shoals?\\",
#        'Commodore, I really must protest.\\', 'nan', 'Now go and get it.',
#        'Ah!  that way direction!', 'This is going to save Elizabeth.',
#        'You’re no longer bound to the Dutchman. You’re free.',
#        'We’ve got her advantage.', 'Larry.',
#        'It doesn’t matter, we’re trapped here by your doing, no different than Jack.',
#        'Slack windward brace and sheets!', 'Jack&#160;!\\',
#        'You loved her. She’s the one, and then you betrayed her.',
#        'Where’s Will?',
#        'Oi! If you do have to get captured, just say Jack Sparrow sent you to settle his debt. Might save your life.',
#        'On the wheel, then, Mr. Turner.',
#        'Odd, isn’t it? But not as odd as this. Come up with this all by your lonesome, did you?',
#        'Eight five’s.', 'You, sailor!\\',
#        'I’ve got a jar of di-irt, I’ve got a jar of di-irt, and guess what’s inside it?',
#        "Mr. Cotton 's... parrot. Same question.\\", 'nan',
#        'It will all have to be redone, all of it! And let that serve as a lesson to the lot of you!',
#        'One can only hope. Take what you can? \\',
#        'You’ve got to do the job though, Jack. You have to ferry souls to the next world. Or end up just like Jones.',
#        'Proper? It is neither proper nor suitable, sir, it is neither acceptable nor adequate. It is in obvious fact an abomination.',
#        'I quite like the sound of that. Captain Jack Sparrow, the last pirate.',
#        'Uh-huh. Well, Mr. Turner , I?ve changed me mind. If you spring me from this cell I swear on pain of death I shall take you to the Black Pearl and your bonny lass. Do we have an accord?\\',
#        'What?s happening?\\',
#        'Once we rescue Jack everything will be fine.',
#        'Oh, so it is that you?ve found a girl. I see. Well, if you?re intending to brave all, hasten to her rescue and so win fair lady?s heart you?ll have to do it alone, mate. I see',
#        'Jack, what did you tell them? No! What about Elizabeth? Jaaack!',
#        'nan', 'You made that up.',
#        'Yes, they’re signed ‘Lord Cutler Beckett of the East India Trading Company.’',
#        'Release her. She’s not part of the bargain.',
#        'Leave him lie! Unless you plan on using him to hit something with.',
#        'Oh, good. No worries, then.\\',
#        'I do! And I practice with them? three hours a day!\\',
#        'That is the child of Bootstrap Bill Turner. His only child, savvy?\\',
#        'I have faith in you. Both of you. Where Will you find him?',
#        'Will! Will! Look at me! Look at me!', 'He fell behind. \\', 'No!',
#        'What are you doing?',
#        'Not sunset, sundown... and rise.  What’s that? I don’t know, what IS that? What do you think?',
#        'The blade is folded steel. That?s gold filigree laid into the handle. If I may. \\',
#        'We being who?', 'But you have heard of me. \\',
#        'Oi!  – Captain Jack Sparrow.', 'I’m gonna kill Jones.',
#        'Barbossa!\\',
#        'Not if you?re the one doing the ambushing. I go in, I convince Barbossa to send his men out with their little boats. You and your mates return to the Dauntless and blast the bejesus outta them with your little cannons, eh?  What do you have to lose?\\',
#        'Come aboard!',
#        'I understand. It’s a game of deception. The game includes all the dice, not just your own. What are they waging?',
#        'All evidence to the contrary.',
#        'No I didn’t. Ah, Tia Dalma, out and about, eh? You lend an agreeable sense of the macabre to any delirium.',
#        'Not yours, his. Jack Sparrow sends his regards.',
#        'On my word do as I say, or I?ll pull this trigger and be lost to Davy Jones? Locker.\\',
#        'I just thought Iâ€™d be married by now. I’m so ready to be married.',
#        'If I may be so bold as to inject my professional opinion. The Pearl was listing near to scuppers after the battle. It?s very unlikely she?ll be able to make good time. Think about it. The Black Pearl . The last real pirate threat in the Caribbean , mate. How can you pass that up?\\',
#        'Jack, it’s me, Will Turner!',
#        'Let?s just say it?s a matter of leverage, eh? \\',
#        'By my reckoning, that account has been settled.',
#        'Sea turtles, mate. A pair of them strapped to my feet.',
#        'Parlay?', 'Jack!', 'Have not!',
#        'What exactly did he put into the chest?',
#        'She’s only a ship, mate.',
#        'I?m going after the Black Pearl.  I know where it?s going to be, and I?m going to take it.\\',
#        '\\',
#        'Oh, she’s not told you? You’ll have loads to talk about while you’re here.  As for you...',
#        'Now may be the only time! I love you. I’ve made my choice. What’s yours?',
#        'You can’t.', 'I know, curious isn’t it?', 'This is madness!',
#        'Then you wouldn’t be here. So you can’t be here. Q.E.D. you’re not really here.',
#        '\\', 'We have a need to travel upriver.', 'Sorry.\\',
#        'Young Mr. Turner and I are to go ashore.\\',
#        'Son?I?m Captain Jack Sparrow. Savvy?\\',
#        'Not quite so well actually. The Brethren Court intends to release her.',
#        'I have doomed us all. It’s the Flying Dutchman!',
#        'What?  I may have deserved that. \\', 'Tie her off!',
#        'Full canvas!',
#        'May I ask you something? Have I ever given you reason not to trust me? Do us a favor&#160;? I know it?s difficult for you, but please stay here and try not to do anything stupid.\\',
#        'My tremendous intuitive sense of the female creature informs me that you are… troubled.',
#        'I love this song! Really bad eggs! Ooh.  When I get the Pearl back, I?m gonna teach it to the whole crew, and we?ll sing it all the time!\\',
#        'There?ll be no living with her after this.\\',
#        'I said to myself, think like Jack.',
#        'Jack’s compass? What does Beckett want with that?',
#        'Aye! Avast! \\', 'He roped a couple of sea turtles?\\',
#        'Parley! That?s the one. Parley! Parley!\\', 'Well done.',
#        'Will&#160;?  Will!\\', 'Pah se ko?',
#        'That’s a sad commentary in and of itself.', 'What is it?',
#        'Of the Brethren Court. Courtesy of Jack.',
#        'The pirates are gathering to fight Beckett, and you’re a pirate.',
#        'How’s mum?',
#        'I knew&#160;?im. Probably one the few who knew him as William Turner . Everyone else just called him Bootstrap or Bootstrap Bill.\\',
#        'With good reason.', 'Is that a lack of faith in Jack… or in me?',
#        'It was my burden to bear.',
#        'I’m still working on that. But I’ll not be going back to the locker, mate, count on that.',
#        'Will!', 'Davy Jones.',
#        'I thought I?d lost it the day they rescued me. It was a gift from my father. He sent it to me. Why did you take it?\\',
#        'Not so easy is it?', 'It’s not over.', 'Is there a way?',
#        'And that was without a single drop of rum.  Send this pestilent traitorous cowhearted yeasty codpiece to the brig.',
#        'Hoist the colors!!!',
#        'No, I have faith in you. You want to know why?',
#        'No mate, I’m free forever. Free to sail the seas beyond the edges of the map, free from death itself.',
#        'Even longer given the deficit of rum.',
#        'I had some help retrieving the Pearl, by the way. Your son.',
#        'Jack. It would never have worked out between us.', 'No, no.',
#        'Jack Sparrow… sent me to settle his debt.',
#        'It goes with your black heart. \\',
#        'Did Lord Beckett tell you that?', 'nan',
#        'That’s the Flying Dutchman?  She doesn’t look like much.',
#        'Agreed.\\', 'What is it?',
#        'Lower the anchor on the right side. On the starboard side!\\',
#        'This is politics.', 'Or worse.', 'Will.',
#        'You’re not making any sense at all.  Any more questions?',
#        'Where?', 'Be my guest.', 'I hate him.',
#        'It certainly has the element of surprise.\\',
#        'Do you?  Heady tonic, holding life and death in the palm of one’s hand.',
#        'He needs the Pearl! Captain Turner needs the Pearl! And you felt guilty. And you and your Brethren Court! Did no one come to save me just because they missed me?  I’m standing over there with them.',
#        'What happened to the chest?',
#        'No, no, not at all by all means, kill the whelp. Just not yet. Wait to lift the curse until the opportune moment. For instance? \\',
#        'Oh, well, you’re welcome, then.', 'What?', 'Done.',
#        'Abandon ship. Into the long boat.', 'On what charges?!',
#        'You can?t. I can. \\', 'How long do we continue not talking?',
#        'I do want to know what it tastes like.',
#        'Yes, it does, you’re sitting on it.',
#        'Jack&#160;?it must be really terrible for you to be trapped on this island.\\',
#        'More acquaintance than friend. How do you know him?',
#        'Is this a dream?',
#        "Of the two of us, I am the only one who hasn't committed mutiny, therefore?my word is the one we'll be trusting. Although?I suppose I should be thanking you because, in fact, if you hadn?t betrayed me and left me to die, I would have an equal share in that curse, same as you. \\",
#        'Belay!', 'Sao Feng!', 'Yeah, it’s going to save Elizabeth.',
#        'It is.\\', 'Sailor. Sailor! There’s no use, you’ve run aground.',
#        'How did you get here?',
#        'That, love, is a dinghy. My vessel is magnificent, and fierce, and huge-ish, and... gone. Why is it gone?',
#        'I couldn’t. It wasn’t your burden to bear.',
#        'I can set you free, mate.', 'King?', 'My compass works fine.',
#        'And after which betrayal did you cut out your heart, I wonder?',
#        'With me killed, you’d arrive at Shipwreck Cove, find its stronghold nigh impregnable, able to withstand blockade for years, and then you’d wish, “Oh, if only there were someone I had not killed inside to assure that the pirates then come outside...”',
#        'What?', 'You’re lying.', 'And you’d have a way of doing that?',
#        'Hard to starboard.', 'No. Don’t do this.',
#        'He’s rescued now, it’s done with. Will, I had no choice.',
#        'I didn?t steal it, if that?s what you mean.\\', '\\',
#        'Hold. Hold!', 'Have not!', 'So this is your able-bodied crew?\\',
#        'nan', 'I?m in the market as it were.\\',
#        'Come to join me Crew, lad? Welcome aboard.', 'A better one.\\',
#        'I knew you’d warm up to me eventually.',
#        'My hands are clean in this... figuratively.',
#        'Calypso is aboard the Black Pearl. Jack has sailed the Black Pearl to Shipwreck Cove.',
#        'James! James! No!', 'Cruel is a matter of perspective.',
#        'Jack Sparrow.  He’s one of the pirate lords.', 'I?ve',
#        'Where does it point?', '\\',
#        'Nothing here is set. These can’t be as accurate as modern charts. Tai Huang',
#        'Me. Dead.', 'My soul. An eternity of servitude.',
#        'No. It’s not a reef!  Get away from the rail!',
#        'There comes a time when one must take responsibility for one’s mistakes.',
#        'Yes, I know your son. Will Turner.',
#        'Are you certain? Is that what you really want most?',
#        'Were I in a divulgatory mood, what then might I divulge?',
#        'Hang on a minute.  It shall be the duty of the king to declare war, parlay with said adversaries... fancy that.',
#        'Jack&#160;? Jack Sparrow&#160;?\\',
#        'Any idea when Jones might release said terrible beastie?',
#        'You left Jack to the Kraken?',
#        'You may kill me, but you may never insult me. Who am I?  Done!',
#        'No, no, leave it.', 'Ah, Hector. It’s been too long, hasn’t it?',
#        'For all that pirates are clever cobs, we are an unimaginative lot when it comes to naming things.',
#        'Elizabeth .\\', 'I knew it!\\',
#        'He thinks we’re a hallucination.',
#        'But I do owe you thanks, Jack.',
#        'I propose an exchange. Will leaves with us, and you can take Jack.',
#        'No, thank you.', 'And better yet, a ship and a crew.',
#        'Darling, I am truly unhappy to have to tell you this, but through an unfortunate and entirely unforeseeable series of circumstances that had nothing whatsoever to do with me, poor Will has been press-ganged into Davy Jones’s Crew.',
#        'Aye.', 'Only a fool’s chance.', 'Raise up the foreyard!',
#        'The ship?s real enough. Therefore its anchorage must be a real place. Where is it?\\',
#        'Elizabeth, we’re not back.',
#        'And what makes you think I need protecting?',
#        'I challenge Davy Jones.',
#        'With your leave, if you’ll still have me.',
#        'I like it. Simple, easy to remember.',
#        "You're the one they're hunting. The pirate.\\",
#        'Yes, I?m fine.\\', 'And you need a crew.',
#        'Sometimes, things come back, mate. We’re living proof, you and me.',
#        'No.\\', 'My father was not a pirate. \\',
#        '&#160;?and then they made me their chief.\\',
#        'I call for a vote.',
#        'Gibbs&#160;! We have to make a stand. We must fight! Load the guns!\\',
#        'You knew this.', 'The locker, you say?',
#        'Recover. At the point of a sword?', 'Yes, the rum is gone.\\',
#        'Jack, the compass, it’s all I need. Elizabeth is in danger. We were arrested for trying to help you. She faces the gallows!',
#        'You’re mad.',
#        'Yes, but The Flying Dutchman already has a Captain, so there’s really –',
#        'Might I enquire as to how you came by these.',
#        'What’s your plan?', 'Tortuga&#160;?\\',
#        'I suspected Commodore Norrington would propose but I must admit, I wasn?t entirely prepared for it.\\',
#        'Not much.', 'I was reunited with my father.',
#        'My father, Will Turner . At the jail, it was only after you learned my name that you agreed to help. Since that?s what I wanted, I didn?t press the matter. I?m not a simpleton, Jack. You knew my father.\\',
#        'Thank you.',
#        'Fortunately, he was mum as the condition in which these souls need be.',
#        'Why don’t you both go ashore and leave the ship in my command... temporarily.',
#        'Fire!',
#        'It is a smart match. He?s a fine man; he?s what any woman should dream of marrying.\\',
#        'Father, come back with us! I won’t leave you!',
#        'Will, how many times must I ask you to call me Elizabeth&#160;?\\',
#        'It?s a pirate medallion.\\', 'Finally. \\',
#        'Dirt. This is a jar of dirt.',
#        'Somehow I doubt Jack Will consider employment the same as being free.',
#        'Keep to the code.\\',
#        'I thought so. I expect you can account for your actions, then?',
#        'No?I mean yes, they are but? but don?t stop.\\',
#        'I once sailed with a geezer lost both of his arms and part of his eye.',
#        'What are YOU doing? Captain gives orders on the ship!',
#        'Only a little. \\',
#        'And some men offer desire as justification for their crimes.',
#        'They done what?s right by them. Can?t expect more than that.\\',
#        'Lost?', 'He elected to stay behind to give us a chance.', 'Yes.',
#        'Then we condemn him to death.\\', 'There’s no boats.',
#        'You?re welcome.\\',
#        '...the bell has been raised from its watery grave; hear its sepulchral tone? A call to all, pay heed the squall, and turn your sails toward home!... yo ho, all together, hoist the colors high. Yo ho, thieves...',
#        'I need that compass of yours, Jack. I must trade it for her freedom.',
#        'Jack.', 'Last time, you left me a pistol with one shot.\\',
#        'Why doesn’t he do something?',
#        'It points to what you want most, and that’s not the Brethren Court, is it?',
#        'I did notice.\\', 'Belay that ‘belay that.’',
#        'Am I not?  Palulay?palu-li-la-la-lulu, parlili? parsnip, pasley, par -  partner, partner?\\',
#        'Mr. Cotton&#160;? do you have the courage and fortitude to follow orders and stay true in the face of danger and almost certain death? Mr. Cotton&#160;! Answer, man!\\',
#        'Because I would think, you’d want to find a way to save Will most.',
#        'Is he that terrifying?',
#        'Doesn’t matter. I’m to find Jack and convince him to return to Port Royal and in exchange the charges against us Will be dropped.',
#        'Whatever you do, don’t miss.',
#        'No worries, mates. Tia Dalma and I go way back. Thick as thieves. Nigh inseparable we are. Were. Have been. Before.',
#        'I prefer rum. Rum’s good.', 'Jack, this is real, we’re here.',
#        'How?s that? The key?s run off.\\',
#        'Jack.  Are you telling the truth?',
#        'It’s funny what a man Will do to forestall his final judgment.',
#        'Oh, it?s beautiful!\\',
#        'Will Turner, do you take me...to be your wife, in sickness and in health, with health being the less likely?',
#        'Keep a weather eye on the horizon.',
#        'With this.  My compass… is unique.', 'And I owe them all money.',
#        'I want you to leave and never come back.\\', 'Mr. Gibbs&#160;?\\',
#        'Captain Jack Sparrow , if you please, sir.\\',
#        'Meanwhile our enemies are bearing down upon us.',
#        'Can’t spot it, must be a tiny little thing hiding somewhere behind the Pearl.',
#        'Jack Sparrow sent me to settle his debt.',
#        'I expect then that we can come to some sort of understanding. I’m here to negotiate.',
#        'I have every faith in your reconciliatory navigational skills, Master Gibbs. Now, where is that monkey? I want to shoot something.',
#        'Depends on the one day.', 'Muhuh.', 'That?s', 'This is wrong.\\',
#        'Bootstrap.',
#        'It points to the thing you want most in this world.',
#        'It?s right here?between you and Jack .\\',
#        'Jack. Cutler Beckett has the heart of Davy Jones. He controls the Flying Dutchman.',
#        'Hey! Hey! Below!\\', 'How could I forget, Miss Swann&#160;?\\',
#        'Well, because &#160;?because the HMS Dauntless, pride of the Royal Navy, is floating just offshore. Waiting for you.\\',
#        'nan', 'And to what do I owe the pleasure of your carbuncle?',
#        'But you were marooned on this island before, weren?t you? So we can escape in the same way you did then.\\',
#        'I suppose you didn?t deserve that one either.\\',
#        'Summoning the Brethren Court, then, is it?',
#        'It?s a fine goal - to be sure -  but it seems to me that a?  makes this one',
#        'What?', 'Come again?',
#        'We’re looking for this.  And what it goes to.', 'Yes, yes.',
#        'Douse the lamps.',
#        'I is arguin’ the point. If there’s pirates a-gatherin’, I’m pointing my ship the other way.',
#        'True enough.  This compass does not point north.', 'Belay!',
#        'We’re the faster?',
#        'Am I to understand that you lot will not be keeping to the code, then?',
#        'No heroes amongst thieves, eh?\\', 'First to the finish, then?',
#        'Will!', 'Oh.', 'And the key Will spare him that?',
#        'Regarding the Brethren Court, no doubt? In exchange for fair compensation, square my debt with Jones, guarantee my freedom?',
#        'Barbossa! Ahead!', 'You?ve got to stop it! Stop it!\\',
#        'I?ve heard of one, supposed to be very fast&#160;? nigh un-catchable?... the Black Pearl.\\',
#        'She is locked up in a prison, bound to hang for helping you.',
#        'Last time?I was here a grand total of three days, all right? Last time \\',
#        'What?', 'I thought not, if it were, there’d be rum.', 'Father!',
#        'Move! \\',
#        'William, tell me something. Have you come because you need my help to rescue a certain distressing damsel? Or rather a damsel in distress? Either one.',
#        'Bootstrap?\\',
#        'Thank goodness for that, because if I wasn’t, this would probably never work.',
#        'Wait! You have to take me to shore. According to the Code of the Order of the Brethren -\\',
#        'At the moment? \\',
#        'William… I shall trade you the compass, if you Will help me…  to find this.',
#        'It?s remarkable how often those two traits coincide.  Everyone stay calm! we are taking over the ship.\\',
#        'I’m gonna need the other one.  It’s always belonged to you. Will you keep it safe?',
#        'What?'], dtype='<U817')

# %%
y_train
# Out:
# array(['Elizabeth', 'Will', 'Jack', 'Jack', 'Jack', 'Jack', 'Will',
#        'Elizabeth', 'Jack', 'Jack', 'Jack', 'Elizabeth', 'Will', 'Will',
#        'Elizabeth', 'Will', 'Jack', 'Will', 'Will', 'Jack', 'Elizabeth',
#        'Jack', 'Elizabeth', 'Elizabeth', 'Elizabeth', 'Will', 'Jack',
#        'Elizabeth', 'Will', 'Elizabeth', 'Will', 'Jack', 'Elizabeth',
#        'Jack', 'Will', 'Jack', 'Jack', 'Elizabeth', 'Will', 'Elizabeth',
#        'Jack', 'Will', 'Jack', 'Will', 'Elizabeth', 'Jack', 'Elizabeth',
#        'Elizabeth', 'Jack', 'Jack', 'Will', 'Jack', 'Jack', 'Will',
#        'Jack', 'Elizabeth', 'Elizabeth', 'Jack', 'Jack', 'Elizabeth',
#        'Will', 'Jack', 'Elizabeth', 'Jack', 'Jack', 'Will', 'Jack',
#        'Will', 'Will', 'Jack', 'Will', 'Will', 'Jack', 'Will', 'Jack',
#        'Elizabeth', 'Jack', 'Will', 'Elizabeth', 'Will', 'Elizabeth',
#        'Will', 'Elizabeth', 'Elizabeth', 'Elizabeth', 'Elizabeth', 'Will',
#        'Will', 'Jack', 'Jack', 'Elizabeth', 'Elizabeth', 'Will', 'Will',
#        'Will', 'Will', 'Jack', 'Will', 'Elizabeth', 'Elizabeth',
#        'Elizabeth', 'Jack', 'Elizabeth', 'Elizabeth', 'Jack', 'Jack',
#        'Elizabeth', 'Will', 'Elizabeth', 'Will', 'Jack', 'Elizabeth',
#        'Elizabeth', 'Elizabeth', 'Jack', 'Elizabeth', 'Jack', 'Elizabeth',
#        'Elizabeth', 'Jack', 'Elizabeth', 'Jack', 'Elizabeth', 'Jack',
#        'Will', 'Elizabeth', 'Will', 'Jack', 'Will', 'Jack', 'Will',
#        'Jack', 'Jack', 'Will', 'Jack', 'Elizabeth', 'Jack', 'Jack',
#        'Elizabeth', 'Elizabeth', 'Elizabeth', 'Jack', 'Jack', 'Jack',
#        'Elizabeth', 'Elizabeth', 'Will', 'Will', 'Will', 'Will', 'Jack',
#        'Will', 'Elizabeth', 'Jack', 'Elizabeth', 'Will', 'Jack', 'Will',
#        'Elizabeth', 'Jack', 'Jack', 'Jack', 'Elizabeth', 'Jack', 'Jack',
#        'Jack', 'Jack', 'Jack', 'Jack', 'Will', 'Jack', 'Will', 'Jack',
#        'Jack', 'Will', 'Will', 'Jack', 'Jack', 'Will', 'Will',
#        'Elizabeth', 'Jack', 'Jack', 'Jack', 'Elizabeth', 'Will', 'Jack',
#        'Elizabeth', 'Will', 'Jack', 'Will', 'Jack', 'Elizabeth', 'Will',
#        'Will', 'Elizabeth', 'Will', 'Elizabeth', 'Elizabeth', 'Elizabeth',
#        'Elizabeth', 'Jack', 'Will', 'Jack', 'Jack', 'Jack', 'Elizabeth',
#        'Jack', 'Jack', 'Will', 'Will', 'Elizabeth', 'Jack', 'Jack',
#        'Jack', 'Will', 'Jack', 'Jack', 'Will', 'Jack', 'Jack', 'Jack',
#        'Will', 'Will', 'Jack', 'Jack', 'Jack', 'Will', 'Jack', 'Jack',
#        'Elizabeth', 'Elizabeth', 'Elizabeth', 'Will', 'Will', 'Will',
#        'Elizabeth', 'Jack', 'Jack', 'Elizabeth', 'Jack', 'Jack',
#        'Elizabeth', 'Elizabeth', 'Elizabeth', 'Jack', 'Jack', 'Elizabeth',
#        'Jack', 'Jack', 'Jack', 'Jack', 'Jack', 'Jack', 'Jack', 'Jack',
#        'Elizabeth', 'Elizabeth', 'Jack', 'Jack', 'Will', 'Jack', 'Jack',
#        'Will', 'Will', 'Elizabeth', 'Jack', 'Jack', 'Will', 'Jack',
#        'Will', 'Will', 'Elizabeth', 'Will', 'Elizabeth', 'Will', 'Jack',
#        'Elizabeth', 'Elizabeth', 'Jack', 'Will', 'Jack', 'Elizabeth',
#        'Jack', 'Jack', 'Jack', 'Elizabeth', 'Jack', 'Jack', 'Jack',
#        'Will', 'Will', 'Jack', 'Will', 'Elizabeth', 'Will', 'Jack',
#        'Jack', 'Jack', 'Will', 'Will', 'Elizabeth', 'Elizabeth', 'Jack',
#        'Elizabeth', 'Elizabeth', 'Will', 'Jack', 'Jack', 'Jack', 'Will',
#        'Elizabeth', 'Elizabeth', 'Elizabeth', 'Will', 'Will', 'Elizabeth',
#        'Jack', 'Jack', 'Will', 'Will', 'Jack', 'Jack', 'Elizabeth',
#        'Jack', 'Jack', 'Jack', 'Elizabeth', 'Jack', 'Elizabeth',
#        'Elizabeth', 'Will', 'Will', 'Will', 'Elizabeth', 'Will',
#        'Elizabeth', 'Will', 'Jack', 'Jack', 'Jack', 'Will', 'Jack',
#        'Will', 'Jack', 'Elizabeth', 'Will', 'Will', 'Will', 'Will',
#        'Elizabeth', 'Jack', 'Will', 'Jack', 'Jack', 'Jack', 'Will',
#        'Jack', 'Elizabeth', 'Jack', 'Jack', 'Jack', 'Jack', 'Jack',
#        'Jack', 'Elizabeth', 'Jack', 'Jack', 'Elizabeth', 'Will',
#        'Elizabeth', 'Elizabeth', 'Will', 'Elizabeth', 'Elizabeth', 'Will',
#        'Jack', 'Elizabeth', 'Jack', 'Will', 'Will', 'Elizabeth',
#        'Elizabeth', 'Jack', 'Jack', 'Elizabeth', 'Jack', 'Jack', 'Will',
#        'Jack', 'Jack', 'Will', 'Will', 'Jack', 'Jack', 'Jack', 'Jack',
#        'Will', 'Will', 'Jack', 'Jack', 'Will', 'Jack', 'Elizabeth',
#        'Will', 'Jack', 'Jack', 'Jack', 'Elizabeth', 'Elizabeth', 'Jack',
#        'Jack', 'Elizabeth', 'Jack', 'Jack', 'Will', 'Jack', 'Jack',
#        'Will', 'Will', 'Will', 'Jack', 'Jack', 'Jack', 'Jack',
#        'Elizabeth', 'Will', 'Will', 'Jack', 'Jack', 'Elizabeth',
#        'Elizabeth', 'Jack', 'Jack', 'Jack', 'Will', 'Will', 'Will',
#        'Jack', 'Will', 'Jack', 'Will', 'Will', 'Elizabeth', 'Jack',
#        'Will', 'Jack', 'Will', 'Jack', 'Jack', 'Jack', 'Elizabeth',
#        'Jack', 'Jack', 'Will', 'Jack', 'Jack', 'Jack', 'Elizabeth',
#        'Elizabeth', 'Jack', 'Will', 'Jack', 'Jack', 'Elizabeth', 'Will',
#        'Jack', 'Jack', 'Will', 'Jack', 'Elizabeth', 'Elizabeth', 'Will',
#        'Elizabeth', 'Elizabeth', 'Jack', 'Will', 'Elizabeth', 'Jack',
#        'Jack', 'Will', 'Will', 'Jack', 'Elizabeth', 'Will', 'Jack',
#        'Jack', 'Will', 'Will', 'Elizabeth', 'Jack', 'Will', 'Jack',
#        'Jack', 'Will', 'Jack', 'Elizabeth', 'Jack', 'Will', 'Jack',
#        'Jack', 'Jack', 'Jack', 'Will', 'Elizabeth', 'Jack', 'Elizabeth',
#        'Jack', 'Jack', 'Jack', 'Jack', 'Jack', 'Jack', 'Will', 'Will',
#        'Jack', 'Will', 'Jack', 'Jack', 'Jack', 'Jack', 'Jack', 'Will',
#        'Elizabeth', 'Will', 'Will', 'Jack', 'Jack', 'Elizabeth', 'Jack',
#        'Jack', 'Elizabeth', 'Elizabeth', 'Elizabeth', 'Jack', 'Jack',
#        'Will', 'Will', 'Will', 'Jack', 'Elizabeth', 'Will', 'Will',
#        'Jack', 'Elizabeth', 'Will', 'Jack', 'Elizabeth', 'Elizabeth',
#        'Jack', 'Jack', 'Jack', 'Elizabeth', 'Elizabeth', 'Will',
#        'Elizabeth', 'Elizabeth', 'Will', 'Will', 'Will', 'Elizabeth',
#        'Elizabeth', 'Jack', 'Will', 'Elizabeth', 'Jack', 'Elizabeth',
#        'Will', 'Will', 'Will', 'Jack', 'Jack', 'Will', 'Jack', 'Jack',
#        'Will', 'Will', 'Jack', 'Elizabeth', 'Will', 'Will', 'Jack',
#        'Jack', 'Elizabeth', 'Will', 'Jack', 'Jack', 'Jack', 'Elizabeth',
#        'Jack', 'Elizabeth', 'Will', 'Jack', 'Jack', 'Elizabeth', 'Jack',
#        'Will', 'Jack', 'Will', 'Jack', 'Elizabeth', 'Elizabeth',
#        'Elizabeth', 'Jack', 'Will', 'Elizabeth', 'Elizabeth', 'Jack',
#        'Will', 'Jack', 'Will', 'Jack', 'Jack', 'Jack', 'Will', 'Jack',
#        'Jack', 'Will', 'Elizabeth', 'Jack', 'Will', 'Jack', 'Elizabeth',
#        'Elizabeth', 'Will', 'Jack', 'Will', 'Will', 'Jack', 'Elizabeth',
#        'Jack', 'Jack', 'Jack', 'Elizabeth', 'Jack', 'Will', 'Jack',
#        'Jack', 'Jack', 'Jack', 'Will', 'Elizabeth', 'Will', 'Will',
#        'Elizabeth', 'Elizabeth', 'Will', 'Jack', 'Will', 'Elizabeth',
#        'Will', 'Will', 'Jack', 'Elizabeth', 'Will', 'Will', 'Jack',
#        'Will', 'Elizabeth', 'Will', 'Jack', 'Elizabeth', 'Will', 'Jack',
#        'Jack', 'Will', 'Will', 'Jack', 'Will', 'Elizabeth', 'Will',
#        'Elizabeth', 'Jack', 'Jack', 'Jack', 'Will', 'Elizabeth', 'Will',
#        'Will', 'Will', 'Elizabeth', 'Jack', 'Will', 'Will', 'Elizabeth',
#        'Elizabeth', 'Elizabeth', 'Elizabeth', 'Jack', 'Jack', 'Will',
#        'Jack', 'Jack', 'Elizabeth', 'Jack', 'Jack', 'Jack', 'Elizabeth',
#        'Jack', 'Elizabeth', 'Elizabeth', 'Elizabeth', 'Elizabeth',
#        'Elizabeth', 'Jack', 'Elizabeth', 'Will', 'Will', 'Jack', 'Will',
#        'Jack', 'Jack', 'Jack', 'Jack', 'Jack', 'Jack', 'Elizabeth',
#        'Will', 'Will', 'Jack', 'Jack', 'Elizabeth', 'Jack', 'Elizabeth',
#        'Jack', 'Elizabeth', 'Elizabeth', 'Will', 'Jack', 'Jack',
#        'Elizabeth', 'Elizabeth', 'Jack', 'Elizabeth', 'Jack', 'Will',
#        'Elizabeth', 'Jack', 'Will', 'Jack', 'Will', 'Elizabeth',
#        'Elizabeth', 'Jack', 'Will', 'Will', 'Will', 'Will', 'Jack',
#        'Jack', 'Jack', 'Elizabeth', 'Will', 'Jack', 'Jack', 'Jack',
#        'Jack', 'Will', 'Elizabeth', 'Jack', 'Jack', 'Jack', 'Jack',
#        'Will', 'Jack', 'Will', 'Jack', 'Elizabeth', 'Jack', 'Will',
#        'Jack', 'Will', 'Elizabeth', 'Jack', 'Will', 'Jack', 'Elizabeth',
#        'Jack', 'Elizabeth', 'Will', 'Jack', 'Will', 'Jack', 'Elizabeth',
#        'Will', 'Jack', 'Jack', 'Will', 'Elizabeth'], dtype='<U9')

# %%
#  Naive Bayesian
text_clf = Pipeline([('vect', CountVectorizer(stop_words="english")), ('tfidf', TfidfTransformer()), ('clf', MultinomialNB())])

text_clf = text_clf.fit(X_train, y_train)
predicted = text_clf.predict(X_test)
np.mean(predicted == y_test)
# Out:
# 0.4621212121212121

# %%
#  SGD-SVM
text_clf_svm = Pipeline([('vect', CountVectorizer(stop_words="english")), ('tfidf', TfidfTransformer()),
                         ('clf-svm', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, n_iter=5, random_state=42))])

text_clf_svm = text_clf_svm.fit(X_train, y_train)
predicted_svm = text_clf_svm.predict(X_test)
np.mean(predicted_svm == y_test)
# Out:
# C:\Users\timot\Anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# 0.4696969696969697

# %%
# Random Forest
text_clf_RanFor = Pipeline([('vect', CountVectorizer(ngram_range=(1, 1))), ('tfidf', TfidfTransformer(use_idf=True)),
                         ('clf-RanFor', RandomForestClassifier(n_estimators=40))])

text_clf_RanFor = text_clf_RanFor.fit(X_train, y_train)
predicted_RanFor = text_clf_RanFor.predict(X_test)
np.mean(predicted_RanFor == y_test)
# Out:
# 0.4659090909090909

# %%
# Linear regression
text_clf_LogReg = Pipeline([('vect', CountVectorizer(ngram_range=(1, 1))), ('tfidf', TfidfTransformer(use_idf=True)),
                         ('clf-RanFor', LogisticRegression())])

text_clf_LogReg = text_clf_LogReg.fit(X_train, y_train)
predicted_LogReg = text_clf_LogReg.predict(X_test)
np.mean(predicted_LogReg == y_test)
# Out:
# 0.48484848484848486

# %%
parameters = {'vect__ngram_range': [(1, 1), (1, 2)], 'tfidf__use_idf': (True, False), 'clf__alpha': (1e-2, 1e-3)}

gs_clf = GridSearchCV(text_clf, parameters, n_jobs=-1)
gs_clf = gs_clf.fit(X_train, y_train)

print(gs_clf.best_score_)
print(gs_clf.best_params_)
# Out:
# 0.47021546261089986
# {'clf__alpha': 0.01, 'tfidf__use_idf': False, 'vect__ngram_range': (1, 1)}

# %%
parameters_svm = {'vect__ngram_range': [(1, 1), (1, 2)], 'tfidf__use_idf': (True, False),'clf-svm__alpha': (1e-2, 1e-3)}

gs_clf_svm = GridSearchCV(text_clf_svm, parameters_svm, n_jobs=-1)
gs_clf_svm = gs_clf_svm.fit(X_train, y_train)


print(gs_clf_svm.best_score_)
print(gs_clf_svm.best_params_)
# Out:
# 0.5006337135614702
# {'clf-svm__alpha': 0.01, 'tfidf__use_idf': False, 'vect__ngram_range': (1, 1)}
# C:\Users\timot\Anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)

# %%
# Parameter-adjusted SDG-SVM
text_clf_svm = Pipeline([('vect', CountVectorizer(ngram_range=(1, 2))), ('tfidf', TfidfTransformer(use_idf=True)),
                         ('clf-svm', SGDClassifier(loss='hinge', penalty='l2',alpha=.001, n_iter=4, random_state=42))])

text_clf_svm = text_clf_svm.fit(X_train, y_train)
predicted_svm = text_clf_svm.predict(X_test)
np.mean(predicted_svm == y_test)
# Out:
# C:\Users\timot\Anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# 0.4393939393939394
